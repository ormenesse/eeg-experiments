# %%
import os
import time
import numpy as np
import pandas as pd
import lightgbm as lgb

from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix
from sklearn.model_selection import validation_curve, train_test_split

from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import gc
import scipy
from scipy import signal
from scipy.signal import butter, lfilter, freqz, stft
from scipy.fft import fft
import numpy as np
import pickle
import tensorflow as tf
from sklearn.metrics import accuracy_score, confusion_matrix, matthews_corrcoef, roc_auc_score, roc_curve

# %% [markdown]
# # Functions

# %%
def plot_eeg(df, name='', save=False):
    fig, rows = plt.subplots(nrows=4, sharex=True, figsize=(17,10))
    fig.patch.set_visible(False)
    fig.tight_layout()

    for ax, col in zip(rows, df.columns):
        ax.plot(df[col])
        ax.title.set_text(col + "_" + name)
        ax.set_ylim(-150, 150)
        ax.patch.set_visible(False)
        
    if not save:
        plt.show()
    else:
        plt.savefig(f'figs/{name}.png')
        plt.close(fig)

# %%
def coluniza(a, nome):
    d = pd.DataFrame(a).T
    d.columns = [nome + "_" + str(col) for col in d.columns]
    return d

# %%
def save_to_file(objeto, nome_arquivo):
    with open(nome_arquivo, 'wb') as output:
        pickle.dump(objeto, output, pickle.HIGHEST_PROTOCOL)


def load_file(nome_arquivo):
    with open(nome_arquivo, 'rb') as input:
        objeto = pickle.load(input)
    return objeto

# %%
def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y

# %%
folder = './Data'

# %%
# %%time
chunks = []
for f in os.listdir(folder):
    print(f)
    if 'Full_Negatives_7nov' in f:
        chunk = pd.read_hdf(os.path.join(folder, f))
        chunks.append(chunk)
neg = pd.concat(chunks, axis=0)
# Out:
# Full_Negatives_7nov0.hdf
# Full_Negatives_7nov1.hdf
# Full_Negatives_7nov2.hdf
# Full_Positives_7nov.hdf
# Wall time: 2min 33s

# %%
neg.columns
# Out:
# Index(['File', 'Paciente', 'Data', 'timestamp_start', 'Target'], dtype='object')

# %%
neg.shape
# Out:
# (30000, 5)

# %%
neg.head()
# Out:
#                File                   Paciente  \
# 0  danila_ramos.edf  RN DALILA RAMOS DOMINGUES
# 1  danila_ramos.edf  RN DALILA RAMOS DOMINGUES
# 2  danila_ramos.edf  RN DALILA RAMOS DOMINGUES
# 3  danila_ramos.edf  RN DALILA RAMOS DOMINGUES
# 4  danila_ramos.edf  RN DALILA RAMOS DOMINGUES
#
#                                                 Data  timestamp_start  Target
# 0        EEG C3-P3  EEG C4-P4  EEG P3-P4  EEG A1-...                0       1
# 1         EEG C3-P3  EEG C4-P4  EEG P3-P4  EEG A1...             9000       1
# 2         EEG C3-P3  EEG C4-P4  EEG P3-P4  EEG A1...            18000       1
# 3         EEG C3-P3  EEG C4-P4  EEG P3-P4  EEG A1...            27000       1
# 4         EEG C3-P3  EEG C4-P4  EEG P3-P4  EEG A1...            36000       1

# %%
neg['Data'].values[0]
# Out:
#       EEG C3-P3  EEG C4-P4  EEG P3-P4  EEG A1-A2
# 0      0.083503  -0.194469  -0.320255   0.093475
# 1      0.627561  -1.572063  -2.581153   0.856685
# 2      2.441086  -6.431905 -10.524846   3.505472
# 3      6.657532 -17.835315 -29.223078   9.768281
# 4     14.455691 -38.728811 -63.442064  21.216426
# ...         ...        ...        ...        ...
# 5995   7.382942  -8.689627  -5.391998   8.690808
# 5996   8.153691  -8.957492  -5.147577   9.117308
# 5997   8.697748  -8.880959  -4.597629   9.386676
# 5998   8.879101  -8.306962  -3.742154   9.341781
# 5999   8.652410  -7.273767  -2.581153   8.915282
#
# [6000 rows x 4 columns]

# %%
#Esqueci do target 0 rs
neg['Target'] = 0

# %%
pos = pd.read_hdf(os.path.join(folder, "Full_Positives_7nov.hdf"))

# %%
pos.shape, neg.shape
# Out:
# ((1540, 5), (30000, 5))

# %%
#junta em um df
df = pd.concat([neg, pos]).reset_index(drop=True)

# %%
df['Target'].value_counts(dropna=False)
# Out:
# 0    30000
# 1     1540
# Name: Target, dtype: int64

# %%
#janelas de crise (alguns bebes tem muito pouco, não são usados para validar)
pos['File'].value_counts()
# Out:
# fabiana_1.edf           646
# gilmara_cristina.edf    357
# murilo_1.edf            211
# remise_jean.edf          94
# danila_ramos_4.edf       85
# sarah_jadach.edf         84
# danila_ramos.edf         56
# juliana_lima_1.edf        5
# juliana_lima_2.edf        1
# marilene.edf              1
# Name: File, dtype: int64

# %%
#janelas de não crise
df['File'].value_counts()
# Out:
# murilo_1.edf            11234
# danila_ramos_5.edf       5550
# danila_ramos_4.edf       3755
# marilene.edf             2946
# remise_jean.edf          2911
# juliana_lima_2.edf       1945
# fabiana_1.edf            1120
# gilmara_cristina.edf      784
# danila_ramos.edf          657
# juliana_lima_1.edf        503
# sarah_jadach.edf           84
# danila_ramos_3.edf         51
# Name: File, dtype: int64

# %% [markdown]
# # Testando em tudo
# Sinais de 4 canais, 6000 amostras, frequencia = 200/sec

# %%
df['Data'].values[0].columns
# Out:
# Index(['EEG C3-P3', 'EEG C4-P4', 'EEG P3-P4', 'EEG A1-A2'], dtype='object')

# %%
stftArrayFinal = None

# %%
from tqdm import tqdm

# %%
fs = 200 # Hz
n = 5*fs # 5 seg

# %%
# %%time
for i,row in tqdm(df.iterrows()):
    
    subDf = row['Data']
    dfArray = []
    #print(row['File'])
    
    for col in ['EEG C3-P3', 'EEG C4-P4', 'EEG P3-P4', 'EEG A1-A2']:
        
        #print(col)
        #print('Min:', np.min(np.abs(subDf[col].values)),'Max:', np.max(np.abs(subDf[col].values)))
        
        
        signalz = subDf[col].values/np.max(np.abs(subDf[col].values))
        signalz = butter_bandpass_filter(signalz, 0.5, 75, fs, order=6)
        dfArray.append(signalz)
    
    #print(' --- ')
    
    stftArray = []
    target = []

    for array in dfArray:

        subArray = [np.abs(np.fft.rfft(array[i:i + n]))/np.max(np.abs(np.fft.rfft(array[i:i + n]))) for i in range(0, len(array), n) if len(array[i:i + n]) == n]

        stftArray.append(np.array(subArray))
    
    stftArray = np.array(stftArray)
    
    if row['Target'] == 0:
        tar = np.ones((stftArray.shape[1],))
    else:
        tar = np.zeros((stftArray.shape[1],))
        
    if i == 0:
        stftArrayFinal = stftArray.copy()
        tgt = tar.copy()
    else:
        stftArrayFinal = np.concatenate((stftArrayFinal,stftArray),axis=1)
        tgt = np.concatenate((tgt,tar),axis=0)
# Out:
# 31540it [26:01:01,  2.97s/it]
# Wall time: 1d 2h 1min 1s

# %%
arrayt = []
for t in tgt:
    if t == 0:
        arrayt.append([0,1])
    else:
        arrayt.append([1,0])
        
tgt  = np.array(arrayt)

# %%
stftArrayFinal = np.expand_dims(np.swapaxes(np.swapaxes(stftArrayFinal,0,1),1,2),axis=3)

# %%
save_to_file(stftArrayFinal, 'stftArray.pkl')
save_to_file(tgt, 'target.pkl')

# %% [markdown]
# ## Model

# %%
del df, neg, pos

# %%
del subDf

# %%
import gc
gc.collect()
# Out:
# 110

# %% [markdown]
# # Neural Network

# %%
stftArrayFinal = load_file('stftArray.pkl')
tgt = load_file('target.pkl')

# %%
#(10816, 201, 5, 1)
stftArrayFinal.shape
# Out:
# (189240, 501, 4, 1)

# %%
#input_shape = (img_rows, img_cols, 1)
input_shape = stftArrayFinal[0].shape
num_classes = 2
batch_size = 64
epochs = 300 #600
input_shape,num_classes
# Out:
# ((501, 4, 1), 2)

# %%
# CRIANDO MODELO
inp = tf.keras.layers.Input(shape=input_shape)
x = tf.keras.layers.Conv2D(32*20, kernel_size=(4, 1), strides=(2, 1))(inp)
x = tf.keras.layers.Activation('relu')(x)
x = tf.keras.layers.AveragePooling2D(pool_size=(3, 1))(x)
x = tf.keras.layers.Dropout(rate=0.25)(x)
x = tf.keras.layers.Conv2D(32*20, kernel_size=(1, 4), strides=(1, 1))(x)
x = tf.keras.layers.Activation('relu')(x)
x = tf.keras.layers.Dropout(rate=0.25)(x)
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(1024, activation='relu')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(rate=0.25)(x)
x = tf.keras.layers.Dense(512, activation='relu')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(rate=0.25)(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(rate=0.25)(x)
x = tf.keras.layers.Dense(64, activation='relu')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(rate=0.25)(x)
x = tf.keras.layers.Dense(16, activation='relu')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(rate=0.25)(x)
#
#
#
eeg = tf.keras.layers.Dense(num_classes,activation='softmax',name='output')(x)

model = tf.keras.models.Model(inputs=inp,outputs=[eeg])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 501, 4, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 249, 4, 640)       3200
# _________________________________________________________________
# activation (Activation)      (None, 249, 4, 640)       0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 83, 4, 640)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 83, 4, 640)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 83, 1, 640)        1639040
# _________________________________________________________________
# activation_1 (Activation)    (None, 83, 1, 640)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 83, 1, 640)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 53120)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              54395904
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               65664
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                1040
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16)                64
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16)                0
# _________________________________________________________________
# output (Dense)               (None, 2)                 34
# =================================================================
# Total params: 56,644,914
# Trainable params: 56,641,426
# Non-trainable params: 3,488
# _________________________________________________________________

# %%
model.compile(loss="categorical_crossentropy",
              optimizer='adam',
              metrics=['accuracy', 'AUC'])

# %%
# train, test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(range(0,len(tgt)),range(0,len(tgt)), test_size=0.2, random_state=42)

# %%
batch_size = 96

# %%
earlyStopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=30,verbose=0, mode='min')
mcp_save = tf.keras.callbacks.ModelCheckpoint('bestAutoSave.hdf5', save_best_only=True, monitor='val_loss', mode='auto')
#reduce_lr_loss = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=0, min_delta=1e-4, mode='auto')

model.fit(
    stftArrayFinal[X_train,:,:,:], tgt[X_train],
    batch_size=batch_size,
    epochs=epochs,
    shuffle = True,
    validation_data=(stftArrayFinal[X_test,:,:,:], tgt[X_test]),
    callbacks=[mcp_save, earlyStopping],
    verbose=1
)
# Out:
# 151392/151392 [==============================] - ETA: 2:04 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 2:03 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 2:03 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 2:03 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 2:03 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 2:03 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 2:02 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 2:02 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 2:02 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 2:02 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 2:02 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 2:01 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 2:01 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 2:01 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 2:01 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 2:01 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 2:00 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 2:00 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 2:00 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 2:00 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 2:00 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:59 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:59 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:59 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:59 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:59 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:58 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:58 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:58 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:58 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:58 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:58 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:57 - loss: 0.0109 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:57 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:57 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:57 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:57 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:56 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:56 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:56 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:56 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:56 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:55 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:55 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:55 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:55 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:55 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:54 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:54 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:54 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:54 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:54 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:53 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:53 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:53 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:53 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:53 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:52 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:52 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:52 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:52 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:52 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:51 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:51 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:51 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:51 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:51 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1:51 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 1: ...
# Epoch 53/300
# 151392/151392 [==============================] - ETA: 5:12 - loss: 0.0055 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:07 - loss: 0.0061 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:06 - loss: 0.0071 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:07 - loss: 0.0074 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:07 - loss: 0.0104 - accuracy: 0.9979 - AUC: 0.99 - ETA: 5:08 - loss: 0.0088 - accuracy: 0.9983 - AUC: 1.00 - ETA: 5:09 - loss: 0.0106 - accuracy: 0.9970 - AUC: 0.99 - ETA: 5:09 - loss: 0.0102 - accuracy: 0.9974 - AUC: 1.00 - ETA: 5:08 - loss: 0.0105 - accuracy: 0.9977 - AUC: 0.99 - ETA: 5:08 - loss: 0.0098 - accuracy: 0.9979 - AUC: 1.00 - ETA: 5:08 - loss: 0.0090 - accuracy: 0.9981 - AUC: 1.00 - ETA: 5:09 - loss: 0.0084 - accuracy: 0.9983 - AUC: 1.00 - ETA: 5:08 - loss: 0.0101 - accuracy: 0.9976 - AUC: 0.99 - ETA: 5:08 - loss: 0.0097 - accuracy: 0.9978 - AUC: 0.99 - ETA: 5:07 - loss: 0.0091 - accuracy: 0.9979 - AUC: 1.00 - ETA: 5:06 - loss: 0.0088 - accuracy: 0.9980 - AUC: 1.00 - ETA: 5:05 - loss: 0.0095 - accuracy: 0.9975 - AUC: 0.99 - ETA: 5:05 - loss: 0.0101 - accuracy: 0.9971 - AUC: 0.99 - ETA: 5:05 - loss: 0.0096 - accuracy: 0.9973 - AUC: 0.99 - ETA: 5:05 - loss: 0.0094 - accuracy: 0.9974 - AUC: 0.99 - ETA: 5:05 - loss: 0.0090 - accuracy: 0.9975 - AUC: 1.00 - ETA: 5:05 - loss: 0.0091 - accuracy: 0.9976 - AUC: 1.00 - ETA: 5:05 - loss: 0.0090 - accuracy: 0.9977 - AUC: 1.00 - ETA: 5:05 - loss: 0.0090 - accuracy: 0.9978 - AUC: 1.00 - ETA: 5:05 - loss: 0.0096 - accuracy: 0.9975 - AUC: 1.00 - ETA: 5:05 - loss: 0.0104 - accuracy: 0.9972 - AUC: 0.99 - ETA: 5:04 - loss: 0.0101 - accuracy: 0.9973 - AUC: 0.99 - ETA: 5:04 - loss: 0.0100 - accuracy: 0.9974 - AUC: 0.99 - ETA: 5:04 - loss: 0.0097 - accuracy: 0.9975 - AUC: 0.99 - ETA: 5:04 - loss: 0.0095 - accuracy: 0.9976 - AUC: 1.00 - ETA: 5:03 - loss: 0.0092 - accuracy: 0.9976 - AUC: 1.00 - ETA: 5:03 - loss: 0.0091 - accuracy: 0.9977 - AUC: 1.00 - ETA: 5:03 - loss: 0.0099 - accuracy: 0.9972 - AUC: 0.99 - ETA: 5:02 - loss: 0.0099 - accuracy: 0.9969 - AUC: 0.99 - ETA: 5:02 - loss: 0.0096 - accuracy: 0.9970 - AUC: 0.99 - ETA: 5:02 - loss: 0.0095 - accuracy: 0.9971 - AUC: 1.00 - ETA: 5:02 - loss: 0.0092 - accuracy: 0.9972 - AUC: 1.00 - ETA: 5:01 - loss: 0.0091 - accuracy: 0.9973 - AUC: 1.00 - ETA: 5:01 - loss: 0.0091 - accuracy: 0.9973 - AUC: 1.00 - ETA: 5:01 - loss: 0.0092 - accuracy: 0.9971 - AUC: 1.00 - ETA: 5:01 - loss: 0.0092 - accuracy: 0.9970 - AUC: 1.00 - ETA: 5:01 - loss: 0.0091 - accuracy: 0.9970 - AUC: 1.00 - ETA: 5:01 - loss: 0.0091 - accuracy: 0.9971 - AUC: 1.00 - ETA: 5:01 - loss: 0.0090 - accuracy: 0.9972 - AUC: 1.00 - ETA: 5:00 - loss: 0.0104 - accuracy: 0.9968 - AUC: 0.99 - ETA: 5:00 - loss: 0.0102 - accuracy: 0.9968 - AUC: 0.99 - ETA: 5:00 - loss: 0.0100 - accuracy: 0.9969 - AUC: 0.99 - ETA: 5:00 - loss: 0.0101 - accuracy: 0.9967 - AUC: 0.99 - ETA: 4:59 - loss: 0.0099 - accuracy: 0.9968 - AUC: 0.99 - ETA: 4:59 - loss: 0.0099 - accuracy: 0.9969 - AUC: 0.99 - ETA: 4:59 - loss: 0.0097 - accuracy: 0.9969 - AUC: 0.99 - ETA: 4:58 - loss: 0.0096 - accuracy: 0.9970 - AUC: 0.99 - ETA: 4:58 - loss: 0.0095 - accuracy: 0.9971 - AUC: 0.99 - ETA: 4:58 - loss: 0.0094 - accuracy: 0.9971 - AUC: 0.99 - ETA: 4:58 - loss: 0.0093 - accuracy: 0.9972 - AUC: 0.99 - ETA: 4:58 - loss: 0.0093 - accuracy: 0.9972 - AUC: 0.99 - ETA: 4:58 - loss: 0.0094 - accuracy: 0.9971 - AUC: 0.99 - ETA: 4:58 - loss: 0.0093 - accuracy: 0.9971 - AUC: 0.99 - ETA: 4:58 - loss: 0.0091 - accuracy: 0.9972 - AUC: 0.99 - ETA: 4:57 - loss: 0.0097 - accuracy: 0.9970 - AUC: 0.99 - ETA: 4:57 - loss: 0.0095 - accuracy: 0.9971 - AUC: 0.99 - ETA: 4:57 - loss: 0.0097 - accuracy: 0.9970 - AUC: 0.99 - ETA: 4:56 - loss: 0.0096 - accuracy: 0.9970 - AUC: 0.99 - ETA: 4:56 - loss: 0.0095 - accuracy: 0.9971 - AUC: 0.99 - ETA: 4:56 - loss: 0.0093 - accuracy: 0.9971 - AUC: 0.99 - ETA: 4:56 - loss: 0.0092 - accuracy: 0.9972 - AUC: 0.99 - ETA: 4:56 - loss: 0.0093 - accuracy: 0.9970 - AUC: 0.99 - ETA: 4:56 - loss: 0.0094 - accuracy: 0.9969 - AUC: 0.99 - ETA: 4: ...
# Epoch 54/300
# 151392/151392 [==============================] - ETA: 5:06 - loss: 0.0025 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:07 - loss: 0.0034 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:07 - loss: 0.0025 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:08 - loss: 0.0020 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:08 - loss: 0.0030 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:06 - loss: 0.0029 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:04 - loss: 0.0031 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:03 - loss: 0.0102 - accuracy: 0.9974 - AUC: 0.99 - ETA: 5:03 - loss: 0.0091 - accuracy: 0.9977 - AUC: 0.99 - ETA: 5:04 - loss: 0.0086 - accuracy: 0.9979 - AUC: 0.99 - ETA: 5:05 - loss: 0.0085 - accuracy: 0.9981 - AUC: 0.99 - ETA: 5:05 - loss: 0.0095 - accuracy: 0.9974 - AUC: 0.99 - ETA: 5:06 - loss: 0.0088 - accuracy: 0.9976 - AUC: 1.00 - ETA: 5:05 - loss: 0.0083 - accuracy: 0.9978 - AUC: 1.00 - ETA: 5:05 - loss: 0.0078 - accuracy: 0.9979 - AUC: 1.00 - ETA: 5:05 - loss: 0.0074 - accuracy: 0.9980 - AUC: 1.00 - ETA: 5:05 - loss: 0.0070 - accuracy: 0.9982 - AUC: 1.00 - ETA: 5:04 - loss: 0.0083 - accuracy: 0.9971 - AUC: 1.00 - ETA: 5:04 - loss: 0.0089 - accuracy: 0.9967 - AUC: 0.99 - ETA: 5:03 - loss: 0.0085 - accuracy: 0.9969 - AUC: 1.00 - ETA: 5:03 - loss: 0.0082 - accuracy: 0.9970 - AUC: 1.00 - ETA: 5:03 - loss: 0.0079 - accuracy: 0.9972 - AUC: 1.00 - ETA: 5:03 - loss: 0.0084 - accuracy: 0.9968 - AUC: 1.00 - ETA: 5:02 - loss: 0.0081 - accuracy: 0.9970 - AUC: 1.00 - ETA: 5:02 - loss: 0.0082 - accuracy: 0.9967 - AUC: 1.00 - ETA: 5:02 - loss: 0.0080 - accuracy: 0.9968 - AUC: 1.00 - ETA: 5:01 - loss: 0.0078 - accuracy: 0.9969 - AUC: 1.00 - ETA: 5:01 - loss: 0.0076 - accuracy: 0.9970 - AUC: 1.00 - ETA: 5:01 - loss: 0.0074 - accuracy: 0.9971 - AUC: 1.00 - ETA: 5:00 - loss: 0.0076 - accuracy: 0.9972 - AUC: 1.00 - ETA: 5:00 - loss: 0.0074 - accuracy: 0.9973 - AUC: 1.00 - ETA: 5:01 - loss: 0.0072 - accuracy: 0.9974 - AUC: 1.00 - ETA: 5:00 - loss: 0.0070 - accuracy: 0.9975 - AUC: 1.00 - ETA: 5:00 - loss: 0.0068 - accuracy: 0.9975 - AUC: 1.00 - ETA: 5:00 - loss: 0.0067 - accuracy: 0.9976 - AUC: 1.00 - ETA: 5:00 - loss: 0.0079 - accuracy: 0.9974 - AUC: 1.00 - ETA: 5:00 - loss: 0.0078 - accuracy: 0.9975 - AUC: 1.00 - ETA: 4:59 - loss: 0.0076 - accuracy: 0.9975 - AUC: 1.00 - ETA: 4:59 - loss: 0.0074 - accuracy: 0.9976 - AUC: 1.00 - ETA: 4:59 - loss: 0.0073 - accuracy: 0.9977 - AUC: 1.00 - ETA: 4:58 - loss: 0.0072 - accuracy: 0.9977 - AUC: 1.00 - ETA: 4:58 - loss: 0.0071 - accuracy: 0.9978 - AUC: 1.00 - ETA: 4:58 - loss: 0.0070 - accuracy: 0.9978 - AUC: 1.00 - ETA: 4:58 - loss: 0.0069 - accuracy: 0.9979 - AUC: 1.00 - ETA: 4:58 - loss: 0.0068 - accuracy: 0.9979 - AUC: 1.00 - ETA: 4:57 - loss: 0.0067 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:57 - loss: 0.0066 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:56 - loss: 0.0065 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:57 - loss: 0.0063 - accuracy: 0.9981 - AUC: 1.00 - ETA: 4:57 - loss: 0.0063 - accuracy: 0.9981 - AUC: 1.00 - ETA: 4:57 - loss: 0.0064 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:56 - loss: 0.0063 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:56 - loss: 0.0066 - accuracy: 0.9978 - AUC: 1.00 - ETA: 4:56 - loss: 0.0065 - accuracy: 0.9979 - AUC: 1.00 - ETA: 4:56 - loss: 0.0069 - accuracy: 0.9977 - AUC: 1.00 - ETA: 4:56 - loss: 0.0071 - accuracy: 0.9976 - AUC: 1.00 - ETA: 4:55 - loss: 0.0070 - accuracy: 0.9976 - AUC: 1.00 - ETA: 4:55 - loss: 0.0068 - accuracy: 0.9977 - AUC: 1.00 - ETA: 4:55 - loss: 0.0070 - accuracy: 0.9975 - AUC: 1.00 - ETA: 4:55 - loss: 0.0075 - accuracy: 0.9972 - AUC: 1.00 - ETA: 4:55 - loss: 0.0074 - accuracy: 0.9973 - AUC: 1.00 - ETA: 4:54 - loss: 0.0073 - accuracy: 0.9973 - AUC: 1.00 - ETA: 4:54 - loss: 0.0072 - accuracy: 0.9974 - AUC: 1.00 - ETA: 4:54 - loss: 0.0079 - accuracy: 0.9971 - AUC: 1.00 - ETA: 4:54 - loss: 0.0080 - accuracy: 0.9970 - AUC: 1.00 - ETA: 4:54 - loss: 0.0079 - accuracy: 0.9970 - AUC: 1.00 - ETA: 4:53 - loss: 0.0078 - accuracy: 0.9970 - AUC: 1.00 - ETA: 4:53 - loss: 0.0077 - accuracy: 0.9971 - AUC: 1.00 - ETA: 4: ...
# Epoch 55/300
# 151392/151392 [==============================] - ETA: 5:06 - loss: 0.0021 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:02 - loss: 0.0015 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:01 - loss: 0.0013 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:03 - loss: 0.0016 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:05 - loss: 0.0196 - accuracy: 0.9958 - AUC: 0.99 - ETA: 5:06 - loss: 0.0172 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:06 - loss: 0.0158 - accuracy: 0.9970 - AUC: 0.99 - ETA: 5:05 - loss: 0.0147 - accuracy: 0.9974 - AUC: 0.99 - ETA: 5:04 - loss: 0.0139 - accuracy: 0.9977 - AUC: 0.99 - ETA: 5:03 - loss: 0.0127 - accuracy: 0.9979 - AUC: 0.99 - ETA: 5:03 - loss: 0.0117 - accuracy: 0.9981 - AUC: 0.99 - ETA: 5:03 - loss: 0.0125 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:03 - loss: 0.0131 - accuracy: 0.9960 - AUC: 0.99 - ETA: 5:03 - loss: 0.0123 - accuracy: 0.9963 - AUC: 0.99 - ETA: 5:03 - loss: 0.0116 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:02 - loss: 0.0112 - accuracy: 0.9967 - AUC: 0.99 - ETA: 5:02 - loss: 0.0106 - accuracy: 0.9969 - AUC: 0.99 - ETA: 5:02 - loss: 0.0102 - accuracy: 0.9971 - AUC: 0.99 - ETA: 5:02 - loss: 0.0106 - accuracy: 0.9967 - AUC: 0.99 - ETA: 5:01 - loss: 0.0106 - accuracy: 0.9964 - AUC: 0.99 - ETA: 5:02 - loss: 0.0113 - accuracy: 0.9960 - AUC: 0.99 - ETA: 5:02 - loss: 0.0112 - accuracy: 0.9957 - AUC: 0.99 - ETA: 5:02 - loss: 0.0107 - accuracy: 0.9959 - AUC: 0.99 - ETA: 5:02 - loss: 0.0103 - accuracy: 0.9961 - AUC: 0.99 - ETA: 5:02 - loss: 0.0101 - accuracy: 0.9962 - AUC: 0.99 - ETA: 5:02 - loss: 0.0098 - accuracy: 0.9964 - AUC: 0.99 - ETA: 5:01 - loss: 0.0100 - accuracy: 0.9961 - AUC: 0.99 - ETA: 5:01 - loss: 0.0101 - accuracy: 0.9959 - AUC: 0.99 - ETA: 5:01 - loss: 0.0099 - accuracy: 0.9960 - AUC: 0.99 - ETA: 5:00 - loss: 0.0104 - accuracy: 0.9958 - AUC: 0.99 - ETA: 5:00 - loss: 0.0104 - accuracy: 0.9956 - AUC: 0.99 - ETA: 5:00 - loss: 0.0101 - accuracy: 0.9958 - AUC: 0.99 - ETA: 5:00 - loss: 0.0100 - accuracy: 0.9959 - AUC: 0.99 - ETA: 5:00 - loss: 0.0118 - accuracy: 0.9954 - AUC: 0.99 - ETA: 5:00 - loss: 0.0115 - accuracy: 0.9955 - AUC: 0.99 - ETA: 5:00 - loss: 0.0112 - accuracy: 0.9957 - AUC: 0.99 - ETA: 5:00 - loss: 0.0111 - accuracy: 0.9958 - AUC: 0.99 - ETA: 5:00 - loss: 0.0113 - accuracy: 0.9956 - AUC: 0.99 - ETA: 5:00 - loss: 0.0111 - accuracy: 0.9957 - AUC: 0.99 - ETA: 4:59 - loss: 0.0108 - accuracy: 0.9958 - AUC: 0.99 - ETA: 4:59 - loss: 0.0113 - accuracy: 0.9957 - AUC: 0.99 - ETA: 4:59 - loss: 0.0111 - accuracy: 0.9958 - AUC: 0.99 - ETA: 4:58 - loss: 0.0108 - accuracy: 0.9959 - AUC: 0.99 - ETA: 4:58 - loss: 0.0106 - accuracy: 0.9960 - AUC: 0.99 - ETA: 4:58 - loss: 0.0104 - accuracy: 0.9961 - AUC: 0.99 - ETA: 4:58 - loss: 0.0102 - accuracy: 0.9962 - AUC: 0.99 - ETA: 4:58 - loss: 0.0101 - accuracy: 0.9962 - AUC: 0.99 - ETA: 4:57 - loss: 0.0101 - accuracy: 0.9963 - AUC: 0.99 - ETA: 4:57 - loss: 0.0103 - accuracy: 0.9962 - AUC: 0.99 - ETA: 4:57 - loss: 0.0101 - accuracy: 0.9962 - AUC: 0.99 - ETA: 4:57 - loss: 0.0106 - accuracy: 0.9961 - AUC: 0.99 - ETA: 4:56 - loss: 0.0106 - accuracy: 0.9960 - AUC: 0.99 - ETA: 4:56 - loss: 0.0104 - accuracy: 0.9961 - AUC: 0.99 - ETA: 4:56 - loss: 0.0110 - accuracy: 0.9959 - AUC: 0.99 - ETA: 4:56 - loss: 0.0108 - accuracy: 0.9960 - AUC: 0.99 - ETA: 4:55 - loss: 0.0107 - accuracy: 0.9961 - AUC: 0.99 - ETA: 4:55 - loss: 0.0105 - accuracy: 0.9962 - AUC: 0.99 - ETA: 4:55 - loss: 0.0116 - accuracy: 0.9959 - AUC: 0.99 - ETA: 4:55 - loss: 0.0116 - accuracy: 0.9958 - AUC: 0.99 - ETA: 4:54 - loss: 0.0115 - accuracy: 0.9958 - AUC: 0.99 - ETA: 4:54 - loss: 0.0114 - accuracy: 0.9959 - AUC: 0.99 - ETA: 4:55 - loss: 0.0113 - accuracy: 0.9960 - AUC: 0.99 - ETA: 4:54 - loss: 0.0111 - accuracy: 0.9960 - AUC: 0.99 - ETA: 4:54 - loss: 0.0111 - accuracy: 0.9959 - AUC: 0.99 - ETA: 4:54 - loss: 0.0110 - accuracy: 0.9960 - AUC: 0.99 - ETA: 4:54 - loss: 0.0111 - accuracy: 0.9959 - AUC: 0.99 - ETA: 4:54 - loss: 0.0109 - accuracy: 0.9960 - AUC: 0.99 - ETA: 4:53 - loss: 0.0110 - accuracy: 0.9959 - AUC: 0.99 - ETA: 4: ...
# Epoch 56/300
# 151392/151392 [==============================] - ETA: 5:04 - loss: 0.0093 - accuracy: 1.0000 - AUC: 1.00 - ETA: 4:59 - loss: 0.0054 - accuracy: 1.0000 - AUC: 1.00 - ETA: 4:57 - loss: 0.0044 - accuracy: 1.0000 - AUC: 1.00 - ETA: 4:55 - loss: 0.0043 - accuracy: 1.0000 - AUC: 1.00 - ETA: 4:54 - loss: 0.0041 - accuracy: 1.0000 - AUC: 1.00 - ETA: 4:54 - loss: 0.0048 - accuracy: 1.0000 - AUC: 1.00 - ETA: 4:53 - loss: 0.0055 - accuracy: 1.0000 - AUC: 1.00 - ETA: 4:53 - loss: 0.0049 - accuracy: 1.0000 - AUC: 1.00 - ETA: 4:53 - loss: 0.0052 - accuracy: 1.0000 - AUC: 1.00 - ETA: 4:52 - loss: 0.0074 - accuracy: 0.9990 - AUC: 1.00 - ETA: 4:52 - loss: 0.0070 - accuracy: 0.9991 - AUC: 1.00 - ETA: 4:52 - loss: 0.0070 - accuracy: 0.9991 - AUC: 1.00 - ETA: 4:52 - loss: 0.0121 - accuracy: 0.9968 - AUC: 0.99 - ETA: 4:53 - loss: 0.0135 - accuracy: 0.9963 - AUC: 0.99 - ETA: 4:53 - loss: 0.0126 - accuracy: 0.9965 - AUC: 0.99 - ETA: 4:52 - loss: 0.0121 - accuracy: 0.9967 - AUC: 0.99 - ETA: 4:52 - loss: 0.0117 - accuracy: 0.9969 - AUC: 0.99 - ETA: 4:52 - loss: 0.0111 - accuracy: 0.9971 - AUC: 0.99 - ETA: 4:52 - loss: 0.0106 - accuracy: 0.9973 - AUC: 0.99 - ETA: 4:52 - loss: 0.0102 - accuracy: 0.9974 - AUC: 0.99 - ETA: 4:51 - loss: 0.0106 - accuracy: 0.9965 - AUC: 0.99 - ETA: 4:51 - loss: 0.0102 - accuracy: 0.9967 - AUC: 0.99 - ETA: 4:51 - loss: 0.0101 - accuracy: 0.9968 - AUC: 0.99 - ETA: 4:51 - loss: 0.0100 - accuracy: 0.9970 - AUC: 0.99 - ETA: 4:51 - loss: 0.0097 - accuracy: 0.9971 - AUC: 0.99 - ETA: 4:51 - loss: 0.0093 - accuracy: 0.9972 - AUC: 0.99 - ETA: 4:51 - loss: 0.0090 - accuracy: 0.9973 - AUC: 1.00 - ETA: 4:51 - loss: 0.0090 - accuracy: 0.9974 - AUC: 1.00 - ETA: 4:50 - loss: 0.0088 - accuracy: 0.9975 - AUC: 1.00 - ETA: 4:50 - loss: 0.0085 - accuracy: 0.9976 - AUC: 1.00 - ETA: 4:50 - loss: 0.0083 - accuracy: 0.9976 - AUC: 1.00 - ETA: 4:50 - loss: 0.0083 - accuracy: 0.9977 - AUC: 1.00 - ETA: 4:50 - loss: 0.0081 - accuracy: 0.9978 - AUC: 1.00 - ETA: 4:50 - loss: 0.0083 - accuracy: 0.9975 - AUC: 1.00 - ETA: 4:50 - loss: 0.0082 - accuracy: 0.9976 - AUC: 1.00 - ETA: 4:49 - loss: 0.0083 - accuracy: 0.9977 - AUC: 1.00 - ETA: 4:50 - loss: 0.0082 - accuracy: 0.9977 - AUC: 1.00 - ETA: 4:50 - loss: 0.0080 - accuracy: 0.9978 - AUC: 1.00 - ETA: 4:50 - loss: 0.0080 - accuracy: 0.9979 - AUC: 1.00 - ETA: 4:50 - loss: 0.0079 - accuracy: 0.9979 - AUC: 1.00 - ETA: 4:50 - loss: 0.0079 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:49 - loss: 0.0081 - accuracy: 0.9978 - AUC: 1.00 - ETA: 4:49 - loss: 0.0079 - accuracy: 0.9978 - AUC: 1.00 - ETA: 4:49 - loss: 0.0081 - accuracy: 0.9976 - AUC: 1.00 - ETA: 4:49 - loss: 0.0080 - accuracy: 0.9977 - AUC: 1.00 - ETA: 4:49 - loss: 0.0080 - accuracy: 0.9977 - AUC: 1.00 - ETA: 4:49 - loss: 0.0079 - accuracy: 0.9978 - AUC: 1.00 - ETA: 4:49 - loss: 0.0080 - accuracy: 0.9978 - AUC: 1.00 - ETA: 4:48 - loss: 0.0080 - accuracy: 0.9979 - AUC: 1.00 - ETA: 4:48 - loss: 0.0079 - accuracy: 0.9979 - AUC: 1.00 - ETA: 4:48 - loss: 0.0078 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:48 - loss: 0.0078 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:48 - loss: 0.0078 - accuracy: 0.9978 - AUC: 1.00 - ETA: 4:48 - loss: 0.0077 - accuracy: 0.9979 - AUC: 1.00 - ETA: 4:47 - loss: 0.0075 - accuracy: 0.9979 - AUC: 1.00 - ETA: 4:47 - loss: 0.0075 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:47 - loss: 0.0074 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:47 - loss: 0.0074 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:47 - loss: 0.0073 - accuracy: 0.9981 - AUC: 1.00 - ETA: 4:47 - loss: 0.0072 - accuracy: 0.9981 - AUC: 1.00 - ETA: 4:46 - loss: 0.0075 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:46 - loss: 0.0074 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:46 - loss: 0.0075 - accuracy: 0.9979 - AUC: 1.00 - ETA: 4:46 - loss: 0.0074 - accuracy: 0.9979 - AUC: 1.00 - ETA: 4:46 - loss: 0.0075 - accuracy: 0.9978 - AUC: 1.00 - ETA: 4:46 - loss: 0.0074 - accuracy: 0.9978 - AUC: 1.00 - ETA: 4:46 - loss: 0.0074 - accuracy: 0.9978 - AUC: 1.00 - ETA: 4:46 - loss: 0.0073 - accuracy: 0.9979 - AUC: 1.00 - ETA: 4: ...
# Epoch 57/300
# 151392/151392 [==============================] - ETA: 5:04 - loss: 0.0078 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:04 - loss: 0.0070 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:05 - loss: 0.0121 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:06 - loss: 0.0093 - accuracy: 0.9974 - AUC: 1.00 - ETA: 5:07 - loss: 0.0100 - accuracy: 0.9979 - AUC: 1.00 - ETA: 5:08 - loss: 0.0155 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:09 - loss: 0.0134 - accuracy: 0.9970 - AUC: 0.99 - ETA: 5:08 - loss: 0.0121 - accuracy: 0.9974 - AUC: 0.99 - ETA: 5:07 - loss: 0.0136 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:06 - loss: 0.0123 - accuracy: 0.9969 - AUC: 0.99 - ETA: 5:06 - loss: 0.0116 - accuracy: 0.9972 - AUC: 0.99 - ETA: 5:05 - loss: 0.0108 - accuracy: 0.9974 - AUC: 0.99 - ETA: 5:04 - loss: 0.0104 - accuracy: 0.9976 - AUC: 0.99 - ETA: 5:04 - loss: 0.0114 - accuracy: 0.9970 - AUC: 0.99 - ETA: 5:04 - loss: 0.0111 - accuracy: 0.9972 - AUC: 0.99 - ETA: 5:04 - loss: 0.0118 - accuracy: 0.9961 - AUC: 0.99 - ETA: 5:04 - loss: 0.0131 - accuracy: 0.9957 - AUC: 0.99 - ETA: 5:05 - loss: 0.0124 - accuracy: 0.9959 - AUC: 0.99 - ETA: 5:05 - loss: 0.0118 - accuracy: 0.9962 - AUC: 0.99 - ETA: 5:04 - loss: 0.0113 - accuracy: 0.9964 - AUC: 0.99 - ETA: 5:04 - loss: 0.0108 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:03 - loss: 0.0108 - accuracy: 0.9962 - AUC: 0.99 - ETA: 5:03 - loss: 0.0104 - accuracy: 0.9964 - AUC: 0.99 - ETA: 5:03 - loss: 0.0100 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:02 - loss: 0.0096 - accuracy: 0.9967 - AUC: 0.99 - ETA: 5:02 - loss: 0.0099 - accuracy: 0.9964 - AUC: 0.99 - ETA: 5:02 - loss: 0.0097 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:01 - loss: 0.0094 - accuracy: 0.9967 - AUC: 0.99 - ETA: 5:01 - loss: 0.0112 - accuracy: 0.9964 - AUC: 0.99 - ETA: 5:00 - loss: 0.0129 - accuracy: 0.9962 - AUC: 0.99 - ETA: 5:00 - loss: 0.0125 - accuracy: 0.9963 - AUC: 0.99 - ETA: 5:00 - loss: 0.0124 - accuracy: 0.9964 - AUC: 0.99 - ETA: 4:59 - loss: 0.0122 - accuracy: 0.9965 - AUC: 0.99 - ETA: 4:59 - loss: 0.0119 - accuracy: 0.9966 - AUC: 0.99 - ETA: 4:59 - loss: 0.0117 - accuracy: 0.9967 - AUC: 0.99 - ETA: 4:59 - loss: 0.0114 - accuracy: 0.9968 - AUC: 0.99 - ETA: 4:59 - loss: 0.0115 - accuracy: 0.9966 - AUC: 0.99 - ETA: 4:59 - loss: 0.0112 - accuracy: 0.9967 - AUC: 0.99 - ETA: 4:59 - loss: 0.0110 - accuracy: 0.9968 - AUC: 0.99 - ETA: 4:59 - loss: 0.0108 - accuracy: 0.9969 - AUC: 0.99 - ETA: 4:58 - loss: 0.0105 - accuracy: 0.9970 - AUC: 0.99 - ETA: 4:58 - loss: 0.0104 - accuracy: 0.9970 - AUC: 0.99 - ETA: 4:58 - loss: 0.0112 - accuracy: 0.9969 - AUC: 0.99 - ETA: 4:58 - loss: 0.0114 - accuracy: 0.9967 - AUC: 0.99 - ETA: 4:57 - loss: 0.0114 - accuracy: 0.9968 - AUC: 0.99 - ETA: 4:57 - loss: 0.0112 - accuracy: 0.9968 - AUC: 0.99 - ETA: 4:57 - loss: 0.0111 - accuracy: 0.9969 - AUC: 0.99 - ETA: 4:57 - loss: 0.0109 - accuracy: 0.9970 - AUC: 0.99 - ETA: 4:56 - loss: 0.0108 - accuracy: 0.9970 - AUC: 0.99 - ETA: 4:56 - loss: 0.0108 - accuracy: 0.9971 - AUC: 0.99 - ETA: 4:56 - loss: 0.0106 - accuracy: 0.9971 - AUC: 0.99 - ETA: 4:56 - loss: 0.0105 - accuracy: 0.9972 - AUC: 0.99 - ETA: 4:55 - loss: 0.0105 - accuracy: 0.9971 - AUC: 0.99 - ETA: 4:55 - loss: 0.0105 - accuracy: 0.9969 - AUC: 0.99 - ETA: 4:55 - loss: 0.0103 - accuracy: 0.9970 - AUC: 0.99 - ETA: 4:55 - loss: 0.0102 - accuracy: 0.9970 - AUC: 0.99 - ETA: 4:55 - loss: 0.0101 - accuracy: 0.9971 - AUC: 0.99 - ETA: 4:55 - loss: 0.0100 - accuracy: 0.9971 - AUC: 0.99 - ETA: 4:54 - loss: 0.0098 - accuracy: 0.9972 - AUC: 0.99 - ETA: 4:54 - loss: 0.0098 - accuracy: 0.9972 - AUC: 0.99 - ETA: 4:54 - loss: 0.0097 - accuracy: 0.9973 - AUC: 0.99 - ETA: 4:54 - loss: 0.0096 - accuracy: 0.9973 - AUC: 0.99 - ETA: 4:54 - loss: 0.0095 - accuracy: 0.9974 - AUC: 0.99 - ETA: 4:53 - loss: 0.0094 - accuracy: 0.9974 - AUC: 0.99 - ETA: 4:53 - loss: 0.0093 - accuracy: 0.9974 - AUC: 0.99 - ETA: 4:53 - loss: 0.0092 - accuracy: 0.9975 - AUC: 0.99 - ETA: 4:53 - loss: 0.0090 - accuracy: 0.9975 - AUC: 0.99 - ETA: 4:53 - loss: 0.0090 - accuracy: 0.9975 - AUC: 0.99 - ETA: 4: ...
# Epoch 58/300
# 151392/151392 [==============================] - ETA: 5:01 - loss: 0.0047 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:01 - loss: 0.0049 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:01 - loss: 0.0035 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:00 - loss: 0.0034 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:00 - loss: 0.0063 - accuracy: 0.9979 - AUC: 1.00 - ETA: 5:00 - loss: 0.0089 - accuracy: 0.9965 - AUC: 1.00 - ETA: 4:59 - loss: 0.0087 - accuracy: 0.9970 - AUC: 1.00 - ETA: 4:59 - loss: 0.0093 - accuracy: 0.9961 - AUC: 1.00 - ETA: 4:59 - loss: 0.0131 - accuracy: 0.9954 - AUC: 0.99 - ETA: 4:59 - loss: 0.0127 - accuracy: 0.9958 - AUC: 0.99 - ETA: 4:59 - loss: 0.0119 - accuracy: 0.9962 - AUC: 0.99 - ETA: 5:00 - loss: 0.0111 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:00 - loss: 0.0110 - accuracy: 0.9968 - AUC: 0.99 - ETA: 5:00 - loss: 0.0109 - accuracy: 0.9970 - AUC: 0.99 - ETA: 5:00 - loss: 0.0103 - accuracy: 0.9972 - AUC: 0.99 - ETA: 5:00 - loss: 0.0098 - accuracy: 0.9974 - AUC: 0.99 - ETA: 5:00 - loss: 0.0108 - accuracy: 0.9969 - AUC: 0.99 - ETA: 4:59 - loss: 0.0117 - accuracy: 0.9965 - AUC: 0.99 - ETA: 4:59 - loss: 0.0117 - accuracy: 0.9962 - AUC: 0.99 - ETA: 4:59 - loss: 0.0119 - accuracy: 0.9958 - AUC: 0.99 - ETA: 4:58 - loss: 0.0120 - accuracy: 0.9955 - AUC: 0.99 - ETA: 4:59 - loss: 0.0114 - accuracy: 0.9957 - AUC: 0.99 - ETA: 4:59 - loss: 0.0111 - accuracy: 0.9959 - AUC: 0.99 - ETA: 4:59 - loss: 0.0110 - accuracy: 0.9957 - AUC: 0.99 - ETA: 4:58 - loss: 0.0112 - accuracy: 0.9954 - AUC: 0.99 - ETA: 4:58 - loss: 0.0108 - accuracy: 0.9956 - AUC: 0.99 - ETA: 4:57 - loss: 0.0108 - accuracy: 0.9958 - AUC: 0.99 - ETA: 4:57 - loss: 0.0106 - accuracy: 0.9959 - AUC: 0.99 - ETA: 4:57 - loss: 0.0103 - accuracy: 0.9960 - AUC: 0.99 - ETA: 4:57 - loss: 0.0100 - accuracy: 0.9962 - AUC: 0.99 - ETA: 4:57 - loss: 0.0104 - accuracy: 0.9956 - AUC: 0.99 - ETA: 4:56 - loss: 0.0101 - accuracy: 0.9958 - AUC: 0.99 - ETA: 4:56 - loss: 0.0099 - accuracy: 0.9959 - AUC: 0.99 - ETA: 4:56 - loss: 0.0097 - accuracy: 0.9960 - AUC: 0.99 - ETA: 4:55 - loss: 0.0094 - accuracy: 0.9961 - AUC: 0.99 - ETA: 4:55 - loss: 0.0094 - accuracy: 0.9962 - AUC: 0.99 - ETA: 4:55 - loss: 0.0096 - accuracy: 0.9961 - AUC: 0.99 - ETA: 4:55 - loss: 0.0094 - accuracy: 0.9962 - AUC: 0.99 - ETA: 4:55 - loss: 0.0091 - accuracy: 0.9963 - AUC: 1.00 - ETA: 4:55 - loss: 0.0090 - accuracy: 0.9964 - AUC: 1.00 - ETA: 4:55 - loss: 0.0088 - accuracy: 0.9964 - AUC: 1.00 - ETA: 4:54 - loss: 0.0087 - accuracy: 0.9965 - AUC: 1.00 - ETA: 4:54 - loss: 0.0085 - accuracy: 0.9966 - AUC: 1.00 - ETA: 4:54 - loss: 0.0083 - accuracy: 0.9967 - AUC: 1.00 - ETA: 4:54 - loss: 0.0092 - accuracy: 0.9965 - AUC: 0.99 - ETA: 4:54 - loss: 0.0090 - accuracy: 0.9966 - AUC: 0.99 - ETA: 4:54 - loss: 0.0089 - accuracy: 0.9967 - AUC: 0.99 - ETA: 4:54 - loss: 0.0088 - accuracy: 0.9967 - AUC: 1.00 - ETA: 4:54 - loss: 0.0088 - accuracy: 0.9968 - AUC: 1.00 - ETA: 4:54 - loss: 0.0087 - accuracy: 0.9969 - AUC: 1.00 - ETA: 4:53 - loss: 0.0086 - accuracy: 0.9969 - AUC: 1.00 - ETA: 4:53 - loss: 0.0088 - accuracy: 0.9968 - AUC: 1.00 - ETA: 4:53 - loss: 0.0087 - accuracy: 0.9969 - AUC: 1.00 - ETA: 4:53 - loss: 0.0085 - accuracy: 0.9969 - AUC: 1.00 - ETA: 4:52 - loss: 0.0084 - accuracy: 0.9970 - AUC: 1.00 - ETA: 4:52 - loss: 0.0086 - accuracy: 0.9968 - AUC: 1.00 - ETA: 4:52 - loss: 0.0086 - accuracy: 0.9969 - AUC: 1.00 - ETA: 4:52 - loss: 0.0085 - accuracy: 0.9969 - AUC: 1.00 - ETA: 4:52 - loss: 0.0084 - accuracy: 0.9970 - AUC: 1.00 - ETA: 4:51 - loss: 0.0083 - accuracy: 0.9970 - AUC: 1.00 - ETA: 4:51 - loss: 0.0083 - accuracy: 0.9971 - AUC: 1.00 - ETA: 4:51 - loss: 0.0086 - accuracy: 0.9968 - AUC: 1.00 - ETA: 4:51 - loss: 0.0085 - accuracy: 0.9969 - AUC: 1.00 - ETA: 4:51 - loss: 0.0084 - accuracy: 0.9969 - AUC: 1.00 - ETA: 4:51 - loss: 0.0083 - accuracy: 0.9970 - AUC: 1.00 - ETA: 4:51 - loss: 0.0082 - accuracy: 0.9970 - AUC: 1.00 - ETA: 4:50 - loss: 0.0081 - accuracy: 0.9970 - AUC: 1.00 - ETA: 4:50 - loss: 0.0083 - accuracy: 0.9969 - AUC: 1.00 - ETA: 4: ...
# Epoch 59/300
# 151392/151392 [==============================] - ETA: 5:00 - loss: 8.6128e-04 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:00 - loss: 0.0195 - accuracy: 0.9948 - AUC: 1.0000   - ETA: 4:59 - loss: 0.0141 - accuracy: 0.9965 - AUC: 1.00 - ETA: 5:02 - loss: 0.0128 - accuracy: 0.9974 - AUC: 0.99 - ETA: 5:02 - loss: 0.0106 - accuracy: 0.9979 - AUC: 0.99 - ETA: 5:03 - loss: 0.0092 - accuracy: 0.9983 - AUC: 0.99 - ETA: 5:03 - loss: 0.0089 - accuracy: 0.9985 - AUC: 0.99 - ETA: 5:02 - loss: 0.0080 - accuracy: 0.9987 - AUC: 1.00 - ETA: 5:03 - loss: 0.0073 - accuracy: 0.9988 - AUC: 1.00 - ETA: 5:03 - loss: 0.0067 - accuracy: 0.9990 - AUC: 1.00 - ETA: 5:02 - loss: 0.0062 - accuracy: 0.9991 - AUC: 1.00 - ETA: 5:02 - loss: 0.0058 - accuracy: 0.9991 - AUC: 1.00 - ETA: 5:02 - loss: 0.0060 - accuracy: 0.9992 - AUC: 1.00 - ETA: 5:02 - loss: 0.0056 - accuracy: 0.9993 - AUC: 1.00 - ETA: 5:02 - loss: 0.0072 - accuracy: 0.9986 - AUC: 1.00 - ETA: 5:02 - loss: 0.0071 - accuracy: 0.9987 - AUC: 1.00 - ETA: 5:02 - loss: 0.0069 - accuracy: 0.9988 - AUC: 1.00 - ETA: 5:02 - loss: 0.0067 - accuracy: 0.9988 - AUC: 1.00 - ETA: 5:01 - loss: 0.0064 - accuracy: 0.9989 - AUC: 1.00 - ETA: 5:01 - loss: 0.0064 - accuracy: 0.9990 - AUC: 1.00 - ETA: 5:00 - loss: 0.0062 - accuracy: 0.9990 - AUC: 1.00 - ETA: 5:00 - loss: 0.0066 - accuracy: 0.9986 - AUC: 1.00 - ETA: 5:00 - loss: 0.0073 - accuracy: 0.9982 - AUC: 1.00 - ETA: 5:00 - loss: 0.0070 - accuracy: 0.9983 - AUC: 1.00 - ETA: 5:00 - loss: 0.0068 - accuracy: 0.9983 - AUC: 1.00 - ETA: 5:00 - loss: 0.0066 - accuracy: 0.9984 - AUC: 1.00 - ETA: 5:00 - loss: 0.0065 - accuracy: 0.9985 - AUC: 1.00 - ETA: 4:59 - loss: 0.0063 - accuracy: 0.9985 - AUC: 1.00 - ETA: 4:59 - loss: 0.0062 - accuracy: 0.9986 - AUC: 1.00 - ETA: 4:59 - loss: 0.0065 - accuracy: 0.9983 - AUC: 1.00 - ETA: 4:58 - loss: 0.0063 - accuracy: 0.9983 - AUC: 1.00 - ETA: 4:58 - loss: 0.0062 - accuracy: 0.9984 - AUC: 1.00 - ETA: 4:58 - loss: 0.0063 - accuracy: 0.9981 - AUC: 1.00 - ETA: 4:58 - loss: 0.0066 - accuracy: 0.9979 - AUC: 1.00 - ETA: 4:58 - loss: 0.0065 - accuracy: 0.9979 - AUC: 1.00 - ETA: 4:58 - loss: 0.0064 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:58 - loss: 0.0063 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:58 - loss: 0.0068 - accuracy: 0.9978 - AUC: 1.00 - ETA: 4:57 - loss: 0.0072 - accuracy: 0.9976 - AUC: 1.00 - ETA: 4:57 - loss: 0.0071 - accuracy: 0.9977 - AUC: 1.00 - ETA: 4:57 - loss: 0.0070 - accuracy: 0.9977 - AUC: 1.00 - ETA: 4:57 - loss: 0.0070 - accuracy: 0.9978 - AUC: 1.00 - ETA: 4:56 - loss: 0.0068 - accuracy: 0.9978 - AUC: 1.00 - ETA: 4:56 - loss: 0.0067 - accuracy: 0.9979 - AUC: 1.00 - ETA: 4:56 - loss: 0.0066 - accuracy: 0.9979 - AUC: 1.00 - ETA: 4:56 - loss: 0.0066 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:56 - loss: 0.0065 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:55 - loss: 0.0065 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:55 - loss: 0.0066 - accuracy: 0.9979 - AUC: 1.00 - ETA: 4:55 - loss: 0.0065 - accuracy: 0.9979 - AUC: 1.00 - ETA: 4:55 - loss: 0.0065 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:55 - loss: 0.0064 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:55 - loss: 0.0064 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:55 - loss: 0.0062 - accuracy: 0.9981 - AUC: 1.00 - ETA: 4:55 - loss: 0.0062 - accuracy: 0.9981 - AUC: 1.00 - ETA: 4:55 - loss: 0.0061 - accuracy: 0.9981 - AUC: 1.00 - ETA: 4:54 - loss: 0.0060 - accuracy: 0.9982 - AUC: 1.00 - ETA: 4:54 - loss: 0.0060 - accuracy: 0.9982 - AUC: 1.00 - ETA: 4:54 - loss: 0.0063 - accuracy: 0.9981 - AUC: 1.00 - ETA: 4:53 - loss: 0.0062 - accuracy: 0.9981 - AUC: 1.00 - ETA: 4:53 - loss: 0.0061 - accuracy: 0.9981 - AUC: 1.00 - ETA: 4:53 - loss: 0.0066 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:53 - loss: 0.0066 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:53 - loss: 0.0065 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:53 - loss: 0.0067 - accuracy: 0.9979 - AUC: 1.00 - ETA: 4:52 - loss: 0.0066 - accuracy: 0.9979 - AUC: 1.00 - ETA: 4:52 - loss: 0.0066 - accuracy: 0.9980 - AUC: 1.00 - ETA: 4:52 - loss: 0.0065 - accuracy: 0.9980 - AUC: 1.00 - ...
# Epoch 60/300
# 151392/151392 [==============================] - ETA: 5:06 - loss: 0.0022 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:09 - loss: 0.0016 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:09 - loss: 0.0012 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:08 - loss: 0.0025 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:06 - loss: 0.0021 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:05 - loss: 0.0038 - accuracy: 0.9983 - AUC: 1.00 - ETA: 5:04 - loss: 0.0043 - accuracy: 0.9985 - AUC: 1.00 - ETA: 5:05 - loss: 0.0041 - accuracy: 0.9987 - AUC: 1.00 - ETA: 5:05 - loss: 0.0038 - accuracy: 0.9988 - AUC: 1.00 - ETA: 5:05 - loss: 0.0040 - accuracy: 0.9990 - AUC: 1.00 - ETA: 5:06 - loss: 0.0039 - accuracy: 0.9991 - AUC: 1.00 - ETA: 5:06 - loss: 0.0036 - accuracy: 0.9991 - AUC: 1.00 - ETA: 5:06 - loss: 0.0037 - accuracy: 0.9992 - AUC: 1.00 - ETA: 5:06 - loss: 0.0041 - accuracy: 0.9993 - AUC: 1.00 - ETA: 5:06 - loss: 0.0041 - accuracy: 0.9993 - AUC: 1.00 - ETA: 5:05 - loss: 0.0039 - accuracy: 0.9993 - AUC: 1.00 - ETA: 5:04 - loss: 0.0053 - accuracy: 0.9988 - AUC: 1.00 - ETA: 5:04 - loss: 0.0066 - accuracy: 0.9977 - AUC: 1.00 - ETA: 5:03 - loss: 0.0066 - accuracy: 0.9978 - AUC: 1.00 - ETA: 5:04 - loss: 0.0080 - accuracy: 0.9974 - AUC: 1.00 - ETA: 5:04 - loss: 0.0077 - accuracy: 0.9975 - AUC: 1.00 - ETA: 5:05 - loss: 0.0074 - accuracy: 0.9976 - AUC: 1.00 - ETA: 5:04 - loss: 0.0071 - accuracy: 0.9977 - AUC: 1.00 - ETA: 5:04 - loss: 0.0070 - accuracy: 0.9978 - AUC: 1.00 - ETA: 5:04 - loss: 0.0072 - accuracy: 0.9975 - AUC: 1.00 - ETA: 5:04 - loss: 0.0069 - accuracy: 0.9976 - AUC: 1.00 - ETA: 5:04 - loss: 0.0076 - accuracy: 0.9973 - AUC: 1.00 - ETA: 5:03 - loss: 0.0074 - accuracy: 0.9974 - AUC: 1.00 - ETA: 5:03 - loss: 0.0084 - accuracy: 0.9971 - AUC: 1.00 - ETA: 5:02 - loss: 0.0083 - accuracy: 0.9972 - AUC: 1.00 - ETA: 5:02 - loss: 0.0081 - accuracy: 0.9973 - AUC: 1.00 - ETA: 5:02 - loss: 0.0081 - accuracy: 0.9974 - AUC: 1.00 - ETA: 5:02 - loss: 0.0078 - accuracy: 0.9975 - AUC: 1.00 - ETA: 5:02 - loss: 0.0077 - accuracy: 0.9975 - AUC: 1.00 - ETA: 5:02 - loss: 0.0075 - accuracy: 0.9976 - AUC: 1.00 - ETA: 5:02 - loss: 0.0081 - accuracy: 0.9974 - AUC: 1.00 - ETA: 5:01 - loss: 0.0081 - accuracy: 0.9975 - AUC: 1.00 - ETA: 5:01 - loss: 0.0080 - accuracy: 0.9975 - AUC: 1.00 - ETA: 5:01 - loss: 0.0083 - accuracy: 0.9973 - AUC: 1.00 - ETA: 5:00 - loss: 0.0081 - accuracy: 0.9974 - AUC: 1.00 - ETA: 5:00 - loss: 0.0079 - accuracy: 0.9975 - AUC: 1.00 - ETA: 5:00 - loss: 0.0078 - accuracy: 0.9975 - AUC: 1.00 - ETA: 4:59 - loss: 0.0077 - accuracy: 0.9976 - AUC: 1.00 - ETA: 4:59 - loss: 0.0082 - accuracy: 0.9974 - AUC: 1.00 - ETA: 4:59 - loss: 0.0082 - accuracy: 0.9975 - AUC: 1.00 - ETA: 4:59 - loss: 0.0080 - accuracy: 0.9975 - AUC: 1.00 - ETA: 4:59 - loss: 0.0079 - accuracy: 0.9976 - AUC: 1.00 - ETA: 4:59 - loss: 0.0078 - accuracy: 0.9976 - AUC: 1.00 - ETA: 4:59 - loss: 0.0078 - accuracy: 0.9974 - AUC: 1.00 - ETA: 4:58 - loss: 0.0079 - accuracy: 0.9973 - AUC: 1.00 - ETA: 4:58 - loss: 0.0078 - accuracy: 0.9973 - AUC: 1.00 - ETA: 4:58 - loss: 0.0078 - accuracy: 0.9974 - AUC: 1.00 - ETA: 4:57 - loss: 0.0076 - accuracy: 0.9974 - AUC: 1.00 - ETA: 4:57 - loss: 0.0077 - accuracy: 0.9975 - AUC: 1.00 - ETA: 4:57 - loss: 0.0076 - accuracy: 0.9975 - AUC: 1.00 - ETA: 4:57 - loss: 0.0074 - accuracy: 0.9976 - AUC: 1.00 - ETA: 4:57 - loss: 0.0074 - accuracy: 0.9976 - AUC: 1.00 - ETA: 4:56 - loss: 0.0073 - accuracy: 0.9977 - AUC: 1.00 - ETA: 4:56 - loss: 0.0072 - accuracy: 0.9977 - AUC: 1.00 - ETA: 4:56 - loss: 0.0072 - accuracy: 0.9976 - AUC: 1.00 - ETA: 4:55 - loss: 0.0071 - accuracy: 0.9976 - AUC: 1.00 - ETA: 4:55 - loss: 0.0079 - accuracy: 0.9973 - AUC: 1.00 - ETA: 4:55 - loss: 0.0084 - accuracy: 0.9972 - AUC: 1.00 - ETA: 4:55 - loss: 0.0084 - accuracy: 0.9972 - AUC: 1.00 - ETA: 4:55 - loss: 0.0086 - accuracy: 0.9971 - AUC: 1.00 - ETA: 4:55 - loss: 0.0087 - accuracy: 0.9970 - AUC: 1.00 - ETA: 4:54 - loss: 0.0085 - accuracy: 0.9970 - AUC: 1.00 - ETA: 4:54 - loss: 0.0084 - accuracy: 0.9971 - AUC: 1.00 - ETA: 4: ...
# Epoch 61/300
# 151392/151392 [==============================] - ETA: 5:03 - loss: 0.0327 - accuracy: 0.9896 - AUC: 0.99 - ETA: 5:03 - loss: 0.0165 - accuracy: 0.9948 - AUC: 0.99 - ETA: 5:09 - loss: 0.0117 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:10 - loss: 0.0089 - accuracy: 0.9974 - AUC: 0.99 - ETA: 5:10 - loss: 0.0073 - accuracy: 0.9979 - AUC: 1.00 - ETA: 5:09 - loss: 0.0064 - accuracy: 0.9983 - AUC: 1.00 - ETA: 5:08 - loss: 0.0057 - accuracy: 0.9985 - AUC: 1.00 - ETA: 5:07 - loss: 0.0055 - accuracy: 0.9987 - AUC: 1.00 - ETA: 5:07 - loss: 0.0051 - accuracy: 0.9988 - AUC: 1.00 - ETA: 5:06 - loss: 0.0077 - accuracy: 0.9979 - AUC: 1.00 - ETA: 5:06 - loss: 0.0110 - accuracy: 0.9962 - AUC: 0.99 - ETA: 5:05 - loss: 0.0101 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:04 - loss: 0.0096 - accuracy: 0.9968 - AUC: 1.00 - ETA: 5:04 - loss: 0.0091 - accuracy: 0.9970 - AUC: 1.00 - ETA: 5:04 - loss: 0.0089 - accuracy: 0.9972 - AUC: 1.00 - ETA: 5:04 - loss: 0.0085 - accuracy: 0.9974 - AUC: 1.00 - ETA: 5:04 - loss: 0.0086 - accuracy: 0.9975 - AUC: 1.00 - ETA: 5:03 - loss: 0.0087 - accuracy: 0.9971 - AUC: 1.00 - ETA: 5:03 - loss: 0.0084 - accuracy: 0.9973 - AUC: 1.00 - ETA: 5:03 - loss: 0.0080 - accuracy: 0.9974 - AUC: 1.00 - ETA: 5:03 - loss: 0.0092 - accuracy: 0.9970 - AUC: 0.99 - ETA: 5:02 - loss: 0.0106 - accuracy: 0.9967 - AUC: 0.99 - ETA: 5:02 - loss: 0.0102 - accuracy: 0.9968 - AUC: 0.99 - ETA: 5:02 - loss: 0.0098 - accuracy: 0.9970 - AUC: 0.99 - ETA: 5:02 - loss: 0.0101 - accuracy: 0.9962 - AUC: 0.99 - ETA: 5:02 - loss: 0.0099 - accuracy: 0.9964 - AUC: 0.99 - ETA: 5:02 - loss: 0.0096 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:01 - loss: 0.0093 - accuracy: 0.9967 - AUC: 1.00 - ETA: 5:01 - loss: 0.0090 - accuracy: 0.9968 - AUC: 1.00 - ETA: 5:01 - loss: 0.0088 - accuracy: 0.9969 - AUC: 1.00 - ETA: 5:00 - loss: 0.0086 - accuracy: 0.9970 - AUC: 1.00 - ETA: 5:00 - loss: 0.0105 - accuracy: 0.9964 - AUC: 0.99 - ETA: 4:59 - loss: 0.0102 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:00 - loss: 0.0100 - accuracy: 0.9966 - AUC: 0.99 - ETA: 5:00 - loss: 0.0099 - accuracy: 0.9964 - AUC: 0.99 - ETA: 5:00 - loss: 0.0097 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:00 - loss: 0.0095 - accuracy: 0.9966 - AUC: 0.99 - ETA: 4:59 - loss: 0.0093 - accuracy: 0.9967 - AUC: 0.99 - ETA: 4:59 - loss: 0.0091 - accuracy: 0.9968 - AUC: 0.99 - ETA: 4:59 - loss: 0.0091 - accuracy: 0.9966 - AUC: 0.99 - ETA: 4:59 - loss: 0.0089 - accuracy: 0.9967 - AUC: 1.00 - ETA: 4:59 - loss: 0.0092 - accuracy: 0.9965 - AUC: 1.00 - ETA: 4:58 - loss: 0.0090 - accuracy: 0.9966 - AUC: 1.00 - ETA: 4:58 - loss: 0.0089 - accuracy: 0.9967 - AUC: 1.00 - ETA: 4:58 - loss: 0.0088 - accuracy: 0.9968 - AUC: 1.00 - ETA: 4:58 - loss: 0.0087 - accuracy: 0.9968 - AUC: 1.00 - ETA: 4:58 - loss: 0.0086 - accuracy: 0.9969 - AUC: 1.00 - ETA: 4:58 - loss: 0.0085 - accuracy: 0.9970 - AUC: 1.00 - ETA: 4:57 - loss: 0.0084 - accuracy: 0.9970 - AUC: 1.00 - ETA: 4:57 - loss: 0.0085 - accuracy: 0.9969 - AUC: 1.00 - ETA: 4:57 - loss: 0.0083 - accuracy: 0.9969 - AUC: 1.00 - ETA: 4:56 - loss: 0.0083 - accuracy: 0.9970 - AUC: 1.00 - ETA: 4:56 - loss: 0.0081 - accuracy: 0.9971 - AUC: 1.00 - ETA: 4:56 - loss: 0.0080 - accuracy: 0.9971 - AUC: 1.00 - ETA: 4:55 - loss: 0.0080 - accuracy: 0.9972 - AUC: 1.00 - ETA: 4:55 - loss: 0.0079 - accuracy: 0.9972 - AUC: 1.00 - ETA: 4:55 - loss: 0.0077 - accuracy: 0.9973 - AUC: 1.00 - ETA: 4:55 - loss: 0.0076 - accuracy: 0.9973 - AUC: 1.00 - ETA: 4:55 - loss: 0.0075 - accuracy: 0.9974 - AUC: 1.00 - ETA: 4:54 - loss: 0.0079 - accuracy: 0.9972 - AUC: 1.00 - ETA: 4:54 - loss: 0.0083 - accuracy: 0.9969 - AUC: 1.00 - ETA: 4:54 - loss: 0.0083 - accuracy: 0.9968 - AUC: 1.00 - ETA: 4:54 - loss: 0.0082 - accuracy: 0.9969 - AUC: 1.00 - ETA: 4:54 - loss: 0.0081 - accuracy: 0.9969 - AUC: 1.00 - ETA: 4:54 - loss: 0.0092 - accuracy: 0.9966 - AUC: 0.99 - ETA: 4:54 - loss: 0.0092 - accuracy: 0.9967 - AUC: 0.99 - ETA: 4:54 - loss: 0.0090 - accuracy: 0.9967 - AUC: 0.99 - ETA: 4:53 - loss: 0.0089 - accuracy: 0.9968 - AUC: 0.99 - ETA: 4: ...
# Epoch 62/300
# 151392/151392 [==============================] - ETA: 5:03 - loss: 0.0036 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:01 - loss: 0.0084 - accuracy: 0.9948 - AUC: 1.00 - ETA: 5:01 - loss: 0.0071 - accuracy: 0.9965 - AUC: 1.00 - ETA: 5:03 - loss: 0.0056 - accuracy: 0.9974 - AUC: 1.00 - ETA: 5:06 - loss: 0.0051 - accuracy: 0.9979 - AUC: 1.00 - ETA: 5:07 - loss: 0.0043 - accuracy: 0.9983 - AUC: 1.00 - ETA: 5:06 - loss: 0.0040 - accuracy: 0.9985 - AUC: 1.00 - ETA: 5:06 - loss: 0.0036 - accuracy: 0.9987 - AUC: 1.00 - ETA: 5:05 - loss: 0.0032 - accuracy: 0.9988 - AUC: 1.00 - ETA: 5:05 - loss: 0.0062 - accuracy: 0.9979 - AUC: 1.00 - ETA: 5:05 - loss: 0.0066 - accuracy: 0.9981 - AUC: 1.00 - ETA: 5:05 - loss: 0.0061 - accuracy: 0.9983 - AUC: 1.00 - ETA: 5:04 - loss: 0.0059 - accuracy: 0.9984 - AUC: 1.00 - ETA: 5:04 - loss: 0.0058 - accuracy: 0.9985 - AUC: 1.00 - ETA: 5:04 - loss: 0.0056 - accuracy: 0.9986 - AUC: 1.00 - ETA: 5:04 - loss: 0.0065 - accuracy: 0.9974 - AUC: 1.00 - ETA: 5:03 - loss: 0.0066 - accuracy: 0.9969 - AUC: 1.00 - ETA: 5:03 - loss: 0.0067 - accuracy: 0.9971 - AUC: 1.00 - ETA: 5:03 - loss: 0.0068 - accuracy: 0.9973 - AUC: 1.00 - ETA: 5:02 - loss: 0.0095 - accuracy: 0.9958 - AUC: 0.99 - ETA: 5:02 - loss: 0.0093 - accuracy: 0.9960 - AUC: 0.99 - ETA: 5:01 - loss: 0.0090 - accuracy: 0.9962 - AUC: 1.00 - ETA: 5:01 - loss: 0.0089 - accuracy: 0.9959 - AUC: 1.00 - ETA: 5:01 - loss: 0.0087 - accuracy: 0.9961 - AUC: 1.00 - ETA: 5:01 - loss: 0.0084 - accuracy: 0.9962 - AUC: 1.00 - ETA: 5:00 - loss: 0.0081 - accuracy: 0.9964 - AUC: 1.00 - ETA: 5:00 - loss: 0.0079 - accuracy: 0.9965 - AUC: 1.00 - ETA: 5:00 - loss: 0.0077 - accuracy: 0.9967 - AUC: 1.00 - ETA: 4:59 - loss: 0.0080 - accuracy: 0.9964 - AUC: 1.00 - ETA: 4:59 - loss: 0.0085 - accuracy: 0.9962 - AUC: 1.00 - ETA: 4:59 - loss: 0.0086 - accuracy: 0.9960 - AUC: 1.00 - ETA: 4:59 - loss: 0.0084 - accuracy: 0.9961 - AUC: 1.00 - ETA: 4:59 - loss: 0.0082 - accuracy: 0.9962 - AUC: 1.00 - ETA: 4:58 - loss: 0.0080 - accuracy: 0.9963 - AUC: 1.00 - ETA: 4:58 - loss: 0.0078 - accuracy: 0.9964 - AUC: 1.00 - ETA: 4:58 - loss: 0.0076 - accuracy: 0.9965 - AUC: 1.00 - ETA: 4:58 - loss: 0.0078 - accuracy: 0.9963 - AUC: 1.00 - ETA: 4:58 - loss: 0.0077 - accuracy: 0.9964 - AUC: 1.00 - ETA: 4:57 - loss: 0.0076 - accuracy: 0.9965 - AUC: 1.00 - ETA: 4:57 - loss: 0.0074 - accuracy: 0.9966 - AUC: 1.00 - ETA: 4:57 - loss: 0.0075 - accuracy: 0.9967 - AUC: 1.00 - ETA: 4:58 - loss: 0.0074 - accuracy: 0.9968 - AUC: 1.00 - ETA: 4:57 - loss: 0.0072 - accuracy: 0.9969 - AUC: 1.00 - ETA: 4:57 - loss: 0.0071 - accuracy: 0.9969 - AUC: 1.00 - ETA: 4:57 - loss: 0.0070 - accuracy: 0.9970 - AUC: 1.00 - ETA: 4:57 - loss: 0.0069 - accuracy: 0.9971 - AUC: 1.00 - ETA: 4:56 - loss: 0.0069 - accuracy: 0.9971 - AUC: 1.00 - ETA: 4:56 - loss: 0.0068 - accuracy: 0.9972 - AUC: 1.00 - ETA: 4:56 - loss: 0.0070 - accuracy: 0.9970 - AUC: 1.00 - ETA: 4:55 - loss: 0.0068 - accuracy: 0.9971 - AUC: 1.00 - ETA: 4:56 - loss: 0.0067 - accuracy: 0.9971 - AUC: 1.00 - ETA: 4:55 - loss: 0.0066 - accuracy: 0.9972 - AUC: 1.00 - ETA: 4:55 - loss: 0.0070 - accuracy: 0.9971 - AUC: 1.00 - ETA: 4:55 - loss: 0.0070 - accuracy: 0.9971 - AUC: 1.00 - ETA: 4:55 - loss: 0.0070 - accuracy: 0.9972 - AUC: 1.00 - ETA: 4:55 - loss: 0.0075 - accuracy: 0.9970 - AUC: 1.00 - ETA: 4:55 - loss: 0.0074 - accuracy: 0.9971 - AUC: 1.00 - ETA: 4:54 - loss: 0.0081 - accuracy: 0.9969 - AUC: 1.00 - ETA: 4:54 - loss: 0.0080 - accuracy: 0.9970 - AUC: 1.00 - ETA: 4:54 - loss: 0.0078 - accuracy: 0.9970 - AUC: 1.00 - ETA: 4:54 - loss: 0.0077 - accuracy: 0.9971 - AUC: 1.00 - ETA: 4:54 - loss: 0.0076 - accuracy: 0.9971 - AUC: 1.00 - ETA: 4:53 - loss: 0.0075 - accuracy: 0.9972 - AUC: 1.00 - ETA: 4:53 - loss: 0.0074 - accuracy: 0.9972 - AUC: 1.00 - ETA: 4:53 - loss: 0.0074 - accuracy: 0.9973 - AUC: 1.00 - ETA: 4:53 - loss: 0.0073 - accuracy: 0.9973 - AUC: 1.00 - ETA: 4:53 - loss: 0.0072 - accuracy: 0.9974 - AUC: 1.00 - ETA: 4:52 - loss: 0.0073 - accuracy: 0.9972 - AUC: 1.00 - ETA: 4: ...
# Epoch 63/300
# ...
# Epoch 77/300
# 151392/151392 [==============================] - ETA: 5:09 - loss: 0.0033 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:04 - loss: 0.0020 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:02 - loss: 0.0021 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:05 - loss: 0.0017 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:08 - loss: 0.0016 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:09 - loss: 0.0018 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:10 - loss: 0.0017 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:09 - loss: 0.0015 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:08 - loss: 0.0023 - accuracy: 0.9988 - AUC: 1.00 - ETA: 5:07 - loss: 0.0067 - accuracy: 0.9979 - AUC: 1.00 - ETA: 5:06 - loss: 0.0061 - accuracy: 0.9981 - AUC: 1.00 - ETA: 5:05 - loss: 0.0068 - accuracy: 0.9974 - AUC: 1.00 - ETA: 5:05 - loss: 0.0070 - accuracy: 0.9968 - AUC: 1.00 - ETA: 5:05 - loss: 0.0084 - accuracy: 0.9955 - AUC: 1.00 - ETA: 5:04 - loss: 0.0079 - accuracy: 0.9958 - AUC: 1.00 - ETA: 5:04 - loss: 0.0079 - accuracy: 0.9961 - AUC: 1.00 - ETA: 5:05 - loss: 0.0074 - accuracy: 0.9963 - AUC: 1.00 - ETA: 5:05 - loss: 0.0071 - accuracy: 0.9965 - AUC: 1.00 - ETA: 5:05 - loss: 0.0067 - accuracy: 0.9967 - AUC: 1.00 - ETA: 5:04 - loss: 0.0064 - accuracy: 0.9969 - AUC: 1.00 - ETA: 5:04 - loss: 0.0062 - accuracy: 0.9970 - AUC: 1.00 - ETA: 5:03 - loss: 0.0062 - accuracy: 0.9972 - AUC: 1.00 - ETA: 5:03 - loss: 0.0062 - accuracy: 0.9973 - AUC: 1.00 - ETA: 5:03 - loss: 0.0059 - accuracy: 0.9974 - AUC: 1.00 - ETA: 5:03 - loss: 0.0072 - accuracy: 0.9967 - AUC: 1.00 - ETA: 5:03 - loss: 0.0070 - accuracy: 0.9968 - AUC: 1.00 - ETA: 5:03 - loss: 0.0069 - accuracy: 0.9969 - AUC: 1.00 - ETA: 5:03 - loss: 0.0067 - accuracy: 0.9970 - AUC: 1.00 - ETA: 5:02 - loss: 0.0065 - accuracy: 0.9971 - AUC: 1.00 - ETA: 5:02 - loss: 0.0071 - accuracy: 0.9969 - AUC: 1.00 - ETA: 5:01 - loss: 0.0071 - accuracy: 0.9970 - AUC: 1.00 - ETA: 5:01 - loss: 0.0069 - accuracy: 0.9971 - AUC: 1.00 - ETA: 5:00 - loss: 0.0067 - accuracy: 0.9972 - AUC: 1.00 - ETA: 5:00 - loss: 0.0067 - accuracy: 0.9972 - AUC: 1.00 - ETA: 5:00 - loss: 0.0065 - accuracy: 0.9973 - AUC: 1.00 - ETA: 5:00 - loss: 0.0069 - accuracy: 0.9971 - AUC: 1.00 - ETA: 5:00 - loss: 0.0068 - accuracy: 0.9972 - AUC: 1.00 - ETA: 5:00 - loss: 0.0066 - accuracy: 0.9973 - AUC: 1.00 - ETA: 4:59 - loss: 0.0064 - accuracy: 0.9973 - AUC: 1.00 - ETA: 4:59 - loss: 0.0063 - accuracy: 0.9974 - AUC: 1.00 - ETA: 4:59 - loss: 0.0063 - accuracy: 0.9975 - AUC: 1.00 - ETA: 4:58 - loss: 0.0062 - accuracy: 0.9975 - AUC: 1.00 - ETA: 4:58 - loss: 0.0061 - accuracy: 0.9976 - AUC: 1.00 - ETA: 4:58 - loss: 0.0061 - accuracy: 0.9976 - AUC: 1.00 - ETA: 4:58 - loss: 0.0064 - accuracy: 0.9975 - AUC: 1.00 - ETA: 4:58 - loss: 0.0069 - accuracy: 0.9973 - AUC: 1.00 - ETA: 4:58 - loss: 0.0069 - accuracy: 0.9971 - AUC: 1.00 - ETA: 4:58 - loss: 0.0068 - accuracy: 0.9972 - AUC: 1.00 - ETA: 4:58 - loss: 0.0067 - accuracy: 0.9972 - AUC: 1.00 - ETA: 4:58 - loss: 0.0068 - accuracy: 0.9971 - AUC: 1.00 - ETA: 4:58 - loss: 0.0067 - accuracy: 0.9971 - AUC: 1.00 - ETA: 4:57 - loss: 0.0073 - accuracy: 0.9968 - AUC: 1.00 - ETA: 4:57 - loss: 0.0074 - accuracy: 0.9967 - AUC: 1.00 - ETA: 4:57 - loss: 0.0077 - accuracy: 0.9965 - AUC: 1.00 - ETA: 4:56 - loss: 0.0080 - accuracy: 0.9964 - AUC: 1.00 - ETA: 4:56 - loss: 0.0080 - accuracy: 0.9965 - AUC: 1.00 - ETA: 4:56 - loss: 0.0078 - accuracy: 0.9965 - AUC: 1.00 - ETA: 4:56 - loss: 0.0077 - accuracy: 0.9966 - AUC: 1.00 - ETA: 4:55 - loss: 0.0076 - accuracy: 0.9966 - AUC: 1.00 - ETA: 4:55 - loss: 0.0075 - accuracy: 0.9967 - AUC: 1.00 - ETA: 4:55 - loss: 0.0074 - accuracy: 0.9968 - AUC: 1.00 - ETA: 4:55 - loss: 0.0076 - accuracy: 0.9966 - AUC: 1.00 - ETA: 4:54 - loss: 0.0075 - accuracy: 0.9967 - AUC: 1.00 - ETA: 4:54 - loss: 0.0075 - accuracy: 0.9967 - AUC: 1.00 - ETA: 4:54 - loss: 0.0074 - accuracy: 0.9968 - AUC: 1.00 - ETA: 4:54 - loss: 0.0074 - accuracy: 0.9968 - AUC: 1.00 - ETA: 4:54 - loss: 0.0074 - accuracy: 0.9967 - AUC: 1.00 - ETA: 4:53 - loss: 0.0074 - accuracy: 0.9968 - AUC: 1.00 - ETA: 4: ...
# Epoch 79/300
# 151392/151392 [==============================] - ETA: 5:11 - loss: 6.2573e-04 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:07 - loss: 3.6138e-04 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:06 - loss: 0.0135 - accuracy: 0.9965 - AUC: 0.9999   - ETA: 5:05 - loss: 0.0112 - accuracy: 0.9974 - AUC: 0.99 - ETA: 5:04 - loss: 0.0090 - accuracy: 0.9979 - AUC: 1.00 - ETA: 5:04 - loss: 0.0092 - accuracy: 0.9983 - AUC: 0.99 - ETA: 5:04 - loss: 0.0080 - accuracy: 0.9985 - AUC: 1.00 - ETA: 5:03 - loss: 0.0071 - accuracy: 0.9987 - AUC: 1.00 - ETA: 5:03 - loss: 0.0081 - accuracy: 0.9977 - AUC: 1.00 - ETA: 5:03 - loss: 0.0073 - accuracy: 0.9979 - AUC: 1.00 - ETA: 5:02 - loss: 0.0067 - accuracy: 0.9981 - AUC: 1.00 - ETA: 5:02 - loss: 0.0062 - accuracy: 0.9983 - AUC: 1.00 - ETA: 5:02 - loss: 0.0068 - accuracy: 0.9976 - AUC: 1.00 - ETA: 5:03 - loss: 0.0070 - accuracy: 0.9978 - AUC: 1.00 - ETA: 5:03 - loss: 0.0095 - accuracy: 0.9972 - AUC: 0.99 - ETA: 5:02 - loss: 0.0089 - accuracy: 0.9974 - AUC: 1.00 - ETA: 5:02 - loss: 0.0085 - accuracy: 0.9975 - AUC: 1.00 - ETA: 5:01 - loss: 0.0109 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:00 - loss: 0.0103 - accuracy: 0.9967 - AUC: 0.99 - ETA: 5:01 - loss: 0.0098 - accuracy: 0.9969 - AUC: 1.00 - ETA: 5:01 - loss: 0.0118 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:02 - loss: 0.0114 - accuracy: 0.9967 - AUC: 0.99 - ETA: 5:01 - loss: 0.0110 - accuracy: 0.9968 - AUC: 0.99 - ETA: 5:01 - loss: 0.0105 - accuracy: 0.9970 - AUC: 0.99 - ETA: 5:01 - loss: 0.0101 - accuracy: 0.9971 - AUC: 1.00 - ETA: 5:01 - loss: 0.0110 - accuracy: 0.9968 - AUC: 0.99 - ETA: 5:00 - loss: 0.0108 - accuracy: 0.9969 - AUC: 0.99 - ETA: 5:00 - loss: 0.0104 - accuracy: 0.9970 - AUC: 1.00 - ETA: 5:00 - loss: 0.0102 - accuracy: 0.9971 - AUC: 1.00 - ETA: 5:00 - loss: 0.0099 - accuracy: 0.9972 - AUC: 1.00 - ETA: 5:00 - loss: 0.0096 - accuracy: 0.9973 - AUC: 1.00 - ETA: 5:00 - loss: 0.0109 - accuracy: 0.9964 - AUC: 0.99 - ETA: 5:00 - loss: 0.0105 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:00 - loss: 0.0102 - accuracy: 0.9966 - AUC: 0.99 - ETA: 5:00 - loss: 0.0100 - accuracy: 0.9967 - AUC: 1.00 - ETA: 4:59 - loss: 0.0102 - accuracy: 0.9965 - AUC: 1.00 - ETA: 4:59 - loss: 0.0101 - accuracy: 0.9966 - AUC: 0.99 - ETA: 4:58 - loss: 0.0102 - accuracy: 0.9964 - AUC: 0.99 - ETA: 4:58 - loss: 0.0099 - accuracy: 0.9965 - AUC: 1.00 - ETA: 4:58 - loss: 0.0116 - accuracy: 0.9961 - AUC: 0.99 - ETA: 4:58 - loss: 0.0116 - accuracy: 0.9962 - AUC: 0.99 - ETA: 4:58 - loss: 0.0113 - accuracy: 0.9963 - AUC: 0.99 - ETA: 4:58 - loss: 0.0111 - accuracy: 0.9964 - AUC: 0.99 - ETA: 4:58 - loss: 0.0108 - accuracy: 0.9964 - AUC: 0.99 - ETA: 4:58 - loss: 0.0106 - accuracy: 0.9965 - AUC: 0.99 - ETA: 4:58 - loss: 0.0111 - accuracy: 0.9964 - AUC: 0.99 - ETA: 4:57 - loss: 0.0108 - accuracy: 0.9965 - AUC: 0.99 - ETA: 4:57 - loss: 0.0107 - accuracy: 0.9965 - AUC: 0.99 - ETA: 4:57 - loss: 0.0105 - accuracy: 0.9966 - AUC: 0.99 - ETA: 4:56 - loss: 0.0106 - accuracy: 0.9965 - AUC: 0.99 - ETA: 4:56 - loss: 0.0104 - accuracy: 0.9965 - AUC: 0.99 - ETA: 4:56 - loss: 0.0104 - accuracy: 0.9966 - AUC: 0.99 - ETA: 4:56 - loss: 0.0102 - accuracy: 0.9967 - AUC: 0.99 - ETA: 4:56 - loss: 0.0101 - accuracy: 0.9967 - AUC: 0.99 - ETA: 4:56 - loss: 0.0100 - accuracy: 0.9968 - AUC: 0.99 - ETA: 4:55 - loss: 0.0098 - accuracy: 0.9968 - AUC: 0.99 - ETA: 4:55 - loss: 0.0102 - accuracy: 0.9967 - AUC: 0.99 - ETA: 4:55 - loss: 0.0100 - accuracy: 0.9968 - AUC: 0.99 - ETA: 4:55 - loss: 0.0099 - accuracy: 0.9968 - AUC: 0.99 - ETA: 4:54 - loss: 0.0098 - accuracy: 0.9969 - AUC: 0.99 - ETA: 4:54 - loss: 0.0097 - accuracy: 0.9969 - AUC: 0.99 - ETA: 4:54 - loss: 0.0103 - accuracy: 0.9968 - AUC: 0.99 - ETA: 4:54 - loss: 0.0103 - accuracy: 0.9969 - AUC: 0.99 - ETA: 4:54 - loss: 0.0101 - accuracy: 0.9969 - AUC: 0.99 - ETA: 4:54 - loss: 0.0100 - accuracy: 0.9970 - AUC: 0.99 - ETA: 4:54 - loss: 0.0101 - accuracy: 0.9968 - AUC: 0.99 - ETA: 4:53 - loss: 0.0100 - accuracy: 0.9969 - AUC: 0.99 - ETA: 4:53 - loss: 0.0099 - accuracy: 0.9969 - AUC: 0. ...
# Epoch 82/300
# 124512/151392 [=======================>......] - ETA: 5:08 - loss: 0.0024 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:06 - loss: 0.0015 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:04 - loss: 0.0010 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:02 - loss: 0.0011 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:01 - loss: 0.0025 - accuracy: 1.0000 - AUC: 1.00 - ETA: 5:03 - loss: 0.0067 - accuracy: 0.9965 - AUC: 1.00 - ETA: 5:05 - loss: 0.0132 - accuracy: 0.9955 - AUC: 0.99 - ETA: 5:06 - loss: 0.0116 - accuracy: 0.9961 - AUC: 0.99 - ETA: 5:05 - loss: 0.0103 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:05 - loss: 0.0095 - accuracy: 0.9969 - AUC: 0.99 - ETA: 5:05 - loss: 0.0151 - accuracy: 0.9962 - AUC: 0.99 - ETA: 5:05 - loss: 0.0140 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:04 - loss: 0.0130 - accuracy: 0.9968 - AUC: 0.99 - ETA: 5:04 - loss: 0.0130 - accuracy: 0.9963 - AUC: 0.99 - ETA: 5:03 - loss: 0.0121 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:02 - loss: 0.0114 - accuracy: 0.9967 - AUC: 0.99 - ETA: 5:02 - loss: 0.0108 - accuracy: 0.9969 - AUC: 0.99 - ETA: 5:02 - loss: 0.0104 - accuracy: 0.9971 - AUC: 0.99 - ETA: 5:02 - loss: 0.0109 - accuracy: 0.9967 - AUC: 0.99 - ETA: 5:03 - loss: 0.0142 - accuracy: 0.9964 - AUC: 0.99 - ETA: 5:02 - loss: 0.0137 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:02 - loss: 0.0136 - accuracy: 0.9962 - AUC: 0.99 - ETA: 5:01 - loss: 0.0130 - accuracy: 0.9964 - AUC: 0.99 - ETA: 5:01 - loss: 0.0125 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:00 - loss: 0.0121 - accuracy: 0.9967 - AUC: 0.99 - ETA: 5:01 - loss: 0.0116 - accuracy: 0.9968 - AUC: 0.99 - ETA: 5:01 - loss: 0.0113 - accuracy: 0.9969 - AUC: 0.99 - ETA: 5:01 - loss: 0.0113 - accuracy: 0.9967 - AUC: 0.99 - ETA: 5:01 - loss: 0.0125 - accuracy: 0.9964 - AUC: 0.99 - ETA: 5:01 - loss: 0.0121 - accuracy: 0.9965 - AUC: 0.99 - ETA: 5:01 - loss: 0.0119 - accuracy: 0.9966 - AUC: 0.99 - ETA: 5:01 - loss: 0.0116 - accuracy: 0.9967 - AUC: 0.99 - ETA: 5:00 - loss: 0.0113 - accuracy: 0.9968 - AUC: 0.99 - ETA: 5:00 - loss: 0.0110 - accuracy: 0.9969 - AUC: 0.99 - ETA: 4:59 - loss: 0.0111 - accuracy: 0.9967 - AUC: 0.99 - ETA: 4:59 - loss: 0.0109 - accuracy: 0.9968 - AUC: 0.99 - ETA: 4:59 - loss: 0.0106 - accuracy: 0.9969 - AUC: 0.99 - ETA: 4:59 - loss: 0.0104 - accuracy: 0.9970 - AUC: 0.99 - ETA: 4:58 - loss: 0.0102 - accuracy: 0.9971 - AUC: 0.99 - ETA: 4:58 - loss: 0.0101 - accuracy: 0.9971 - AUC: 0.99 - ETA: 4:58 - loss: 0.0101 - accuracy: 0.9972 - AUC: 0.99 - ETA: 4:57 - loss: 0.0099 - accuracy: 0.9973 - AUC: 0.99 - ETA: 4:57 - loss: 0.0097 - accuracy: 0.9973 - AUC: 0.99 - ETA: 4:57 - loss: 0.0096 - accuracy: 0.9974 - AUC: 0.99 - ETA: 4:57 - loss: 0.0094 - accuracy: 0.9975 - AUC: 0.99 - ETA: 4:57 - loss: 0.0092 - accuracy: 0.9975 - AUC: 0.99 - ETA: 4:57 - loss: 0.0090 - accuracy: 0.9976 - AUC: 0.99 - ETA: 4:57 - loss: 0.0089 - accuracy: 0.9976 - AUC: 0.99 - ETA: 4:56 - loss: 0.0087 - accuracy: 0.9977 - AUC: 0.99 - ETA: 4:56 - loss: 0.0085 - accuracy: 0.9977 - AUC: 0.99 - ETA: 4:56 - loss: 0.0090 - accuracy: 0.9975 - AUC: 0.99 - ETA: 4:56 - loss: 0.0089 - accuracy: 0.9976 - AUC: 0.99 - ETA: 4:55 - loss: 0.0088 - accuracy: 0.9976 - AUC: 0.99 - ETA: 4:55 - loss: 0.0087 - accuracy: 0.9977 - AUC: 0.99 - ETA: 4:55 - loss: 0.0091 - accuracy: 0.9975 - AUC: 0.99 - ETA: 4:54 - loss: 0.0090 - accuracy: 0.9976 - AUC: 0.99 - ETA: 4:54 - loss: 0.0088 - accuracy: 0.9976 - AUC: 0.99 - ETA: 4:54 - loss: 0.0088 - accuracy: 0.9975 - AUC: 0.99 - ETA: 4:54 - loss: 0.0087 - accuracy: 0.9975 - AUC: 0.99 - ETA: 4:53 - loss: 0.0086 - accuracy: 0.9976 - AUC: 0.99 - ETA: 4:53 - loss: 0.0085 - accuracy: 0.9976 - AUC: 0.99 - ETA: 4:53 - loss: 0.0087 - accuracy: 0.9975 - AUC: 0.99 - ETA: 4:53 - loss: 0.0089 - accuracy: 0.9974 - AUC: 0.99 - ETA: 4:53 - loss: 0.0088 - accuracy: 0.9974 - AUC: 0.99 - ETA: 4:53 - loss: 0.0087 - accuracy: 0.9974 - AUC: 0.99 - ETA: 4:53 - loss: 0.0085 - accuracy: 0.9975 - AUC: 0.99 - ETA: 4:52 - loss: 0.0085 - accuracy: 0.9975 - AUC: 0.99 - ETA: 4:52 - loss: 0.0084 - accuracy: 0.9975 - AUC: 0.99 - ETA: 4: ...

# %%
model.save_weights("./modelo.hdf5")

# %% [markdown]
# ## Test

# %%
(pd.DataFrame(tgt))[0].value_counts(normalize=True)

# %%
def cria_curva_roc_auc(modelo,df_verificacao,df_target):
    predictions = modelo.predict(df_verificacao)
    fpr, tpr, threshold = roc_curve(df_target, predictions[:,1])
    plt.figure(figsize=(8,8))
    lw = 2
    plt.plot(fpr, tpr, color='darkorange',lw=lw, label='ROC curve (area = %0.2f)' % roc_auc_score(df_target, predictions[:,1]))
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic REAIS')
    plt.legend(loc="lower right")
    plt.show()
    
def limiar_escore(modelo,df_verificacao,df_target):
    #Imprimindo limiar de Escore
    predictions = modelo.predict(df_verificacao)
    fpr, tpr, threshold = roc_curve(df_target, predictions[:,1])
    i = np.arange(len(tpr)) 
    roc = pd.DataFrame({'tf' : pd.Series(tpr-(1-fpr), index=i), 'threshold' : pd.Series(threshold, index=i)})
    roc_t = roc.loc[(roc.tf-0).abs().argsort()[:1]]
    print('Limiar que maxima especificidade e sensitividade:')
    print(list(roc_t['threshold']))
    #analisando modelo com novo limiar
    tn, fp, fn, tp = confusion_matrix(df_target, [1 if item>=list(roc_t['threshold'])[0] else 0 for item in predictions[:,1]]).ravel()
    Precision = tp/(tp+fp)
    Recall = tp/(tp+fn)
    acuracia = (tp+tn)/(tn+fp+fn+tp)
    F = (2*Precision*Recall)/(Precision+Recall)
    print('Precision',Precision)
    print('Recall',Recall)
    print('Acuracia',acuracia)
    print('F-Score',F)
    print('Roc-AUC', roc_auc_score(df_target, predictions[:,1]))

# %%
cria_curva_roc_auc(model,stftArrayFinal[X_train,:,:,:],tgt[X_train,1])

# %%
limiar_escore(model,stftArrayFinal[X_train,:,:,:],tgt[X_train,1])

# %%
cria_curva_roc_auc(model,stftArrayFinal[X_test,:,:,:],tgt[X_test,1])

# %%
limiar_escore(model,stftArrayFinal[X_test,:,:,:],tgt[X_test,1])
# Out:
# Limiar que maxima especificidade e sensitividade:
# [0.0017901735845953226]
# Precision 0.699177438307873
# Recall 0.9786184210526315
# Acuracia 0.9786778693722258
# F-Score 0.8156271418779986
# Roc-AUC 0.9960730446880445

# %% [markdown]
# # Using Lime to Detect Best Samples array

# %%
import lime

# %%
from lime import lime_image

# %%
from skimage.segmentation import mark_boundaries

# %%
def new_predict_fn(images):
    images = images[:,:,:,0]
    #print(images.shape)
    #print(np.expand_dims(images,axis=3).shape)
    #print(model.predict(np.expand_dims(images,axis=3)))
    return model.predict(np.expand_dims(images,axis=3))

# %%
model.load_weights('bestAutoSave.hdf5')

# %%
explainer = lime_image.LimeImageExplainer()

# %%
randIntArray = np.random.randint(0,189240,size=5000)

# %%
heatmapArray = []
for i in tqdm(randIntArray):
    explanation = explainer.explain_instance( stftArrayFinal[i,:,:,0], new_predict_fn, top_labels=5, hide_color=0, num_samples=100)
    ind =  explanation.top_labels[0]
    #Map each explanation weight to the corresponding superpixel
    dict_heatmap = dict(explanation.local_exp[ind])
    heatmapArray.append(np.vectorize(dict_heatmap.get)(explanation.segments.T))
# Out:
# HBox(children=(IntProgress(value=0, max=5000), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# ...
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))

# %%
save_to_file(heatmapArray,'heatmapArray.pkl')

# %%
np.array(heatmapArray).shape
# Out:
# (5000, 4, 501)

# %%
heat = np.mean(np.array(heatmapArray)[list(np.where(tgt[randIntArray,0] == 1 )[0])],axis=0)

# %%
#Plot. The visualization makes more sense if a symmetrical colorbar is used.
plt.figure(figsize=(40,5))
plt.imshow(heat, cmap = 'RdBu', vmin  = heat.min(), vmax = heat.max(),extent=[0, 100, 8, 0],resample=True)
plt.title('Frequências mais importantes quando há a ocorrência de convulsão')
plt.grid(axis='y')
plt.xlabel('Frequência (Hz)')
plt.colorbar()

# %%
ax = plt.figure(figsize=(40,5))
ax = plt.imshow(heat, cmap = 'RdBu', vmin  = heat.min(), vmax = heat.max(),extent=[0, 100, 8, 0],resample=True)
ax = plt.title('Frequências mais importantes quando há a ocorrência de convulsão')
ax = plt.grid(axis='y')
ax = plt.xlabel('Frequência (Hz)')
ax = plt.colorbar()
plt.savefig('convulsao.png')

# %%
heat = np.mean(np.array(heatmapArray)[list(np.where(tgt[randIntArray,0] == 0 )[0])],axis=0)

# %%
#Plot. The visualization makes more sense if a symmetrical colorbar is used.
plt.figure(figsize=(40,5))
plt.title('Frequências mais importantes quando não há a ocorrência de convulsão')
plt.imshow(heat, cmap = 'RdBu', vmin  = heat.min(), vmax = heat.max(),extent=[0, 100, 8, 0],resample=True)
plt.grid(axis='y')
plt.xlabel('Frequência (Hz)')
plt.colorbar()

# %%
ax = plt.figure(figsize=(40,5))
ax = plt.imshow(heat, cmap = 'RdBu', vmin  = heat.min(), vmax = heat.max(),extent=[0, 100, 8, 0],resample=True)
ax = plt.title('Frequências mais importantes quando não há a ocorrência de convulsão')
ax = plt.grid(axis='y')
ax = plt.xlabel('Frequência (Hz)')
ax = plt.colorbar()
plt.savefig('naoconvulsao.png')

# %% [markdown]
# FIM
